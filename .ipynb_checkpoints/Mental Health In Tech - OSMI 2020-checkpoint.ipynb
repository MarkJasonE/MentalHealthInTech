# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

#Uses Jupyter's own backend to plot
# %matplotlib inline

# %% [markdown]
# **Show all rows**

# %%
#Show all rows and columns
pd.set_option("max_rows", None)
pd.set_option("max_columns", None)

# %% [markdown]
# #To do - questions to answer
#
# Get to know the dataset
#  - ~~Initial visualization~~
#  - What type of mental disorders are there?
#
#
# Data cleaning
#  - Change column titles
#  - Change all NAN to numerical values
#      - Gender
#          - ~~Change gender to male, female, other~~
#          - ~~Visualize % of gender and age in each country~~
#      - Mental health disorder columns
#          - Anxiety Disorder (Generalized, Social, Phobia, etc)
#          - Mood Disorder (Depression, Bipolar Disorder, etc)
#          - Psychotic Disorder (Schizophrenia, Schizoaffective, etc)
#          - Eating Disorder (Anorexia, Bulimia, etc)
#          - Attention Deficit Hyperactivity Disorder
#          - Personality Disorder (Borderline, Antisocial, Paranoid, etc)
#          - Obsessive-Compulsive Disorder
#          - Post-Traumatic Stress Disorder
#          - Stress Response Syndromes
#          - Dissociative Disorder
#          - Substance Use Disorder
#          - Addictive Disorder
#
#
# Question to answer
#  - Are people who are self imployed have more mental disorders?
#      - Look how many self employed/employee there are
#      - Compare how many of them **currently** have mental disorders
#  - Have you ever been diagnosed with mental health disorder
#      - If possible, what disorders do you believe you have?
#          - Find out which disorders answers belong to this question
#      - If so, what disorders were you diagnosed with?
#          - Find out which disorders answers belong to this question
#  - Do you currently have a mental disorder?
#  - Have you had a mental health disorder in the past?

# %% [markdown]
# ## Data exploration

# %%
#Read original CSV, make a copy of it
surveyO = pd.read_csv("Dataset/Mental_Health_in_Tech_2020_OSMI.csv")
surveyC = surveyO.copy() #Make changes here instead of the original df

# %%
surveyC.head(5)
# Out:
#                                user  self_employed num_employees  \
# 0  zwrffw6ykfo82ft1twvzwrffw6c6wsfv              1           NaN
# 1  zhdmhaa8r0125c4zmoi7qzhdmtjrakhm              1           NaN
# 2  x4itwa9hnlw7qke4y5xibx4itwa9yzl5              1           NaN
# 3  x3v3oimu5pn0043n8x3v3oizaybhwwto              1           NaN
# 4  uyp6re7bhnyx6gez09uyp6re72z0e4e4              1           NaN
#
#    is_tech_company  is_role_in_tech mh_coverage options_in_mh_coverage  \
# 0              NaN              NaN         NaN                    NaN
# 1              NaN              NaN         NaN                    NaN
# 2              NaN              NaN         NaN                    NaN
# 3              NaN              NaN         NaN                    NaN
# 4              NaN              NaN         NaN                    NaN
#
#   employer_mh_disc employer_offer_mh_res mh_sa_anonimity mh_leave_difficulty  \
# 0              NaN                   NaN             NaN                 NaN
# 1              NaN                   NaN             NaN                 NaN
# 2              NaN                   NaN             NaN                 NaN
# 3              NaN                   NaN             NaN                 NaN
# 4              NaN                   NaN             NaN                 NaN
#
#   coworker_comfort_reveal_ph_mh_disc supervisor_comfort_mh_disc  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                        NaN
# 4                                NaN                        NaN
#
#    employer_reveal_mh_disc employer_reveal_mh_disc_results  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
#   coworker_comfort_mh_disc  coworker_reveal_mh_disc  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#   coworker_reveal_mh_disc_results  coworker_confine_mh_disc  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#   Describe the conversation your coworker had with you about their mental health (please do not use names).  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Overall, how much importance does your employer place on physical health?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Overall, how much importance does your employer place on mental health?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#   Do you know local or online resources to seek help for a mental health issue?  \
# 0                               No, I don't know any
# 1                                Yes, I know several
# 2                               No, I don't know any
# 3                               No, I don't know any
# 4                                Yes, I know several
#
#   If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?  \
# 0                      No, because it doesn't matter
# 1                                        Yes, always
# 2          No, because it would impact me negatively
# 3                      No, because it doesn't matter
# 4          No, because it would impact me negatively
#
#   If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?  \
# 0                                                NaN
# 1                                         Positively
# 2                                         Negatively
# 3                                         Negatively
# 4                                         Negatively
#
#   If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?  \
# 0                      No, because it doesn't matter
# 1                                        Yes, always
# 2          No, because it would impact me negatively
# 3          No, because it would impact me negatively
# 4                                        Yes, always
#
#   If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?  \
# 0                                       I'm not sure
# 1                                         Positively
# 2                                         Negatively
# 3                                         Negatively
# 4                                       I'm not sure
#
#   Do you believe your productivity is ever affected by a mental health issue?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?  \
# 0                                              1-25%
# 1                                              1-25%
# 2                                            76-100%
# 3                                              1-25%
# 4                                             26-50%
#
#    *Do you have previous employers?*  \
# 0                                  1
# 1                                  1
# 2                                  0
# 3                                  0
# 4                                  0
#
#    Was your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Have your previous employers provided mental health benefits?  \
# 0                                       I don't know
# 1                                  Yes, they all did
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Were you aware of the options for mental health care provided by your previous employers?  \
# 0                                 N/A (none offered)
# 1                    Yes, I was aware of all of them
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?  \
# 0                                           None did
# 1                                  Yes, they all did
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Did your previous employers provide resources to learn more about mental health disorders and how to seek help?  \
# 0                                           None did
# 1                                  Yes, they all did
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?  \
# 0                                       I don't know
# 1                                        Yes, always
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?  \
# 0                                    Physical health
# 1                                    Physical health
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Would you have been willing to discuss your mental health with your direct supervisor(s)?  \
# 0                No, none of my previous supervisors
# 1                Yes, all of my previous supervisors
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Did you ever discuss your mental health with your previous employer?  \
# 0                                                0.0
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Would you have been willing to discuss your mental health with your coworkers at previous employers?  \
# 0                   At some of my previous employers
# 1               Yes, at all of my previous employers
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Did you ever discuss your mental health with a previous coworker(s)?  \
# 0                                                0.0
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Describe the conversation you had with your previous coworkers about your mental health including their reactions.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Did you ever have a previous coworker discuss their or another coworker's mental health with you?  \
# 0                                                0.0
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Describe the conversation your coworker had with you about their mental health (please do not use names)..1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Overall, how much importance did your previous employer place on physical health?  \
# 0                                                6.0
# 1                                               10.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Overall, how much importance did your previous employer place on mental health?  \
# 0                                                0.0
# 1                                               10.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   currently_has_mhd  \
# 0        Don't Know
# 1               Yes
# 2               Yes
# 3               Yes
# 4        Don't Know
#
#   Have you ever been *diagnosed* with a mental health disorder?  \
# 0                                                NaN
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                NaN
#
#    Anxiety Disorder (Generalized, Social, Phobia, etc)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mood Disorder (Depression, Bipolar Disorder, etc)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Psychotic Disorder (Schizophrenia, Schizoaffective, etc)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Eating Disorder (Anorexia, Bulimia, etc)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Attention Deficit Hyperactivity Disorder  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Personality Disorder (Borderline, Antisocial, Paranoid, etc)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Obsessive-Compulsive Disorder  Post-Traumatic Stress Disorder  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    Stress Response Syndromes  Dissociative Disorder  Substance Use Disorder  \
# 0                        NaN                    NaN                     NaN
# 1                        NaN                    NaN                     NaN
# 2                        NaN                    NaN                     NaN
# 3                        NaN                    NaN                     NaN
# 4                        NaN                    NaN                     NaN
#
#    Addictive Disorder  Other  \
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2                 NaN    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN
#
#   Anxiety Disorder (Generalized, Social, Phobia, etc).1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Mood Disorder (Depression, Bipolar Disorder, etc).1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Eating Disorder (Anorexia, Bulimia, etc).1  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Attention Deficit Hyperactivity Disorder.1  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Personality Disorder (Borderline, Antisocial, Paranoid, etc).1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Obsessive-Compulsive Disorder.1 Post-traumatic Stress Disorder  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   Stress Response Syndromes.1 Dissociative Disorder.1  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
#
#    Substance Use Disorder.1 Addictive Disorder.1  Other.1  \
# 0                       NaN                  NaN      NaN
# 1                       NaN                  NaN      NaN
# 2                       NaN                  NaN      NaN
# 3                       NaN                  NaN      NaN
# 4                       NaN                  NaN      NaN
#
#   Anxiety Disorder (Generalized, Social, Phobia, etc).2  \
# 0                                                NaN
# 1  Anxiety Disorder (Generalized, Social, Phobia,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Mood Disorder (Depression, Bipolar Disorder, etc).2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Eating Disorder (Anorexia, Bulimia, etc).2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Attention Deficit Hyperactivity Disorder.2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Personality Disorder (Borderline, Antisocial, Paranoid, etc).2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Obsessive-Compulsive Disorder.2 Post-traumatic Stress Disorder.1  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
#   Stress Response Syndromes.2 Dissociative Disorder.2  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
#
#   Substance Use Disorder.2 Addictive Disorder.2 Other.2  \
# 0                      NaN                  NaN     NaN
# 1                      NaN                  NaN     NaN
# 2                      NaN                  NaN     NaN
# 3                      NaN                  NaN     NaN
# 4                      NaN                  NaN     NaN
#
#   Have you had a mental health disorder in the past?  \
# 0                                         Don't Know
# 1                                                Yes
# 2                                                NaN
# 3                                                NaN
# 4                                                 No
#
#    Have you ever sought treatment for a mental health disorder from a mental health professional?  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Do you have a family history of mental illness?  \
# 0                                             Yes
# 1                                             Yes
# 2                                             Yes
# 3                                             Yes
# 4                                    I don't know
#
#   If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*  \
# 0                               Not applicable to me
# 1                                              Never
# 2                                              Often
# 3                                              Often
# 4                                             Rarely
#
#   If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*  \
# 0                                          Sometimes
# 1                                              Never
# 2                                              Often
# 3                                          Sometimes
# 4                                              Often
#
#   Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?  \
# 0                                                NaN
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#    How willing would you be to share with friends and family that you have a mental illness?  \
# 0                                                  5
# 1                                                 10
# 2                                                  5
# 3                                                  1
# 4                                                  5
#
#   Would you be willing to bring up a physical health issue with a potential employer in an interview?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                              Maybe
# 3                                                Yes
# 4                                                Yes
#
#                                      Why or why not?  \
# 0  It depend on if the discussion would have an i...
# 1                                                NaN
# 2                    It affects my employment or job
# 3                                                NaN
# 4                      it will affect another person
#
#   Would you bring up your *mental* health with a potential employer in an interview?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#                                    Why or why not?.1  \
# 0  Same reason. But I believe this would have a g...
# 1                                                NaN
# 2                                  It affects my job
# 3                                                NaN
# 4  it will affect my personality to the other person
#
#    Are you openly identified at work as a person with a mental health issue?  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Has being identified as a person with a mental health issue affected your career?  \
# 0                                                NaN
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    How has it affected your career?  \
# 0                               NaN
# 1                              10.0
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?  \
# 0                                                  5
# 1                                                 10
# 2                                                  0
# 3                                                  6
# 4                                                  3
#
#   Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?  \
# 0                                     Maybe/Not sure
# 1                                    Yes, I observed
# 2                                 Yes, I experienced
# 3                                                 No
# 4                                    Yes, I observed
#
#   Describe the circumstances of the badly handled or unsupportive response.  \
# 0                                                NaN
# 1                                                NaN
# 2  Some times with my boss, he will response prop...
# 3                                                NaN
# 4            taking less to that person or ignorance
#
#   Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?  \
# 0                                 Yes, I experienced
# 1                                    Yes, I observed
# 2                                 Yes, I experienced
# 3                                     Maybe/Not sure
# 4                                     Maybe/Not sure
#
#    Describe the circumstances of the supportive or well handled response.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Overall, how well do you think the tech industry supports employees with mental health issues?  \
# 0                                                  2
# 1                                                  5
# 2                                                  1
# 3                                                  1
# 4                                                  3
#
#   Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                                NaN
# 1                                                NaN
# 2  They should understand and we should talk openely
# 3                                                NaN
# 4  behaving well with them and give them a good t...
#
#   If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                                NaN
# 1                                                NaN
# 2       mental health should be a law by government.
# 3                                                NaN
# 4                                                 no
#
#    Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    age  gender                   country  \
# 0   45    Male  United States of America
# 1   24  female                    Russia
# 2   46    Male                     India
# 3   25  Female                    Canada
# 4   25       F                    Canada
#
#   What US state or territory do you *live* in? What is your race? Other.3  \
# 0                                  Connecticut              White     NaN
# 1                                          NaN                NaN     NaN
# 2                                          NaN                NaN     NaN
# 3                                          NaN                NaN     NaN
# 4                                          NaN                NaN     NaN
#
#   What country do you *work* in? What US state or territory do you *work* in?
# 0       United States of America                                  Connecticut
# 1                         Russia                                          NaN
# 2                          India                                          NaN
# 3                         Canada                                          NaN
# 4                         Canada                                          NaN

# %%
#Get bigger picture: data types, readability
surveyC.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 120 columns):
#  #    Column                                                                                                                                                                                                                            Dtype
# ---   ------                                                                                                                                                                                                                            -----
#  0    user                                                                                                                                                                                                                              object
#  1    *Are you self-employed?*                                                                                                                                                                                                          int64
#  2    How many employees does your company or organization have?                                                                                                                                                                        object
#  3    Is your employer primarily a tech company/organization?                                                                                                                                                                           float64
#  4    Is your primary role within your company related to tech/IT?                                                                                                                                                                      float64
#  5    Does your employer provide mental health benefits as part of healthcare coverage?                                                                                                                                                 object
#  6    Do you know the options for mental health care available under your employer-provided health coverage?                                                                                                                            object
#  7    Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?                                                                                            object
#  8    Does your employer offer resources to learn more about mental health disorders and options for seeking help?                                                                                                                      object
#  9    Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?                                                                                    object
#  10   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?                                                                                              object
#  11   Would you feel more comfortable talking to your coworkers about your physical health or your mental health?                                                                                                                       object
#  12   Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?                                                                                                                                       object
#  13   Have you ever discussed your mental health with your employer?                                                                                                                                                                    float64
#  14   Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.                                               object
#  15   Would you feel comfortable discussing a mental health issue with your coworkers?                                                                                                                                                  object
#  16   Have you ever discussed your mental health with coworkers?                                                                                                                                                                        float64
#  17   Describe the conversation with coworkers you had about your mental health including their reactions.                                                                                                                              object
#  18   Have you ever had a coworker discuss their or another coworker's mental health with you?                                                                                                                                          float64
#  19   Describe the conversation your coworker had with you about their mental health (please do not use names).                                                                                                                         object
#  20   Overall, how much importance does your employer place on physical health?                                                                                                                                                         float64
#  21   Overall, how much importance does your employer place on mental health?                                                                                                                                                           float64
#  22   Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?                                                                                                            float64
#  23   Do you know local or online resources to seek help for a mental health issue?                                                                                                                                                     object
#  24   If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?                                                                                                      object
#  25   If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?                                                                                                     object
#  26   If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?                                                                                                            object
#  27   If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?                                                                                                           object
#  28   Do you believe your productivity is ever affected by a mental health issue?                                                                                                                                                       object
#  29   If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?                                                                                              object
#  30   *Do you have previous employers?*                                                                                                                                                                                                 int64
#  31   Was your employer primarily a tech company/organization?                                                                                                                                                                          float64
#  32   Have your previous employers provided mental health benefits?                                                                                                                                                                     object
#  33   Were you aware of the options for mental health care provided by your previous employers?                                                                                                                                         object
#  34   Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?                                                                                                 object
#  35   Did your previous employers provide resources to learn more about mental health disorders and how to seek help?                                                                                                                   object
#  36   Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?                                                                                      object
#  37   Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?                                                                                                          object
#  38   Would you have been willing to discuss your mental health with your direct supervisor(s)?                                                                                                                                         object
#  39   Did you ever discuss your mental health with your previous employer?                                                                                                                                                              float64
#  40   Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.                                                object
#  41   Would you have been willing to discuss your mental health with your coworkers at previous employers?                                                                                                                              object
#  42   Did you ever discuss your mental health with a previous coworker(s)?                                                                                                                                                              float64
#  43   Describe the conversation you had with your previous coworkers about your mental health including their reactions.                                                                                                                object
#  44   Did you ever have a previous coworker discuss their or another coworker's mental health with you?                                                                                                                                 float64
#  45   Describe the conversation your coworker had with you about their mental health (please do not use names)..1                                                                                                                       object
#  46   Overall, how much importance did your previous employer place on physical health?                                                                                                                                                 float64
#  47   Overall, how much importance did your previous employer place on mental health?                                                                                                                                                   float64
#  48   Do you *currently* have a mental health disorder?                                                                                                                                                                                 object
#  49   Have you ever been *diagnosed* with a mental health disorder?                                                                                                                                                                     object
#  50   Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                                                                                               float64
#  51   Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                                                 float64
#  52   Psychotic Disorder (Schizophrenia, Schizoaffective, etc)                                                                                                                                                                          float64
#  53   Eating Disorder (Anorexia, Bulimia, etc)                                                                                                                                                                                          float64
#  54   Attention Deficit Hyperactivity Disorder                                                                                                                                                                                          float64
#  55   Personality Disorder (Borderline, Antisocial, Paranoid, etc)                                                                                                                                                                      float64
#  56   Obsessive-Compulsive Disorder                                                                                                                                                                                                     float64
#  57   Post-Traumatic Stress Disorder                                                                                                                                                                                                    float64
#  58   Stress Response Syndromes                                                                                                                                                                                                         float64
#  59   Dissociative Disorder                                                                                                                                                                                                             float64
#  60   Substance Use Disorder                                                                                                                                                                                                            float64
#  61   Addictive Disorder                                                                                                                                                                                                                float64
#  62   Other                                                                                                                                                                                                                             float64
#  63   Anxiety Disorder (Generalized, Social, Phobia, etc).1                                                                                                                                                                             object
#  64   Mood Disorder (Depression, Bipolar Disorder, etc).1                                                                                                                                                                               object
#  65   Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1                                                                                                                                                                        float64
#  66   Eating Disorder (Anorexia, Bulimia, etc).1                                                                                                                                                                                        object
#  67   Attention Deficit Hyperactivity Disorder.1                                                                                                                                                                                        object
#  68   Personality Disorder (Borderline, Antisocial, Paranoid, etc).1                                                                                                                                                                    object
#  69   Obsessive-Compulsive Disorder.1                                                                                                                                                                                                   object
#  70   Post-traumatic Stress Disorder                                                                                                                                                                                                    object
#  71   Stress Response Syndromes.1                                                                                                                                                                                                       object
#  72   Dissociative Disorder.1                                                                                                                                                                                                           object
#  73   Substance Use Disorder.1                                                                                                                                                                                                          float64
#  74   Addictive Disorder.1                                                                                                                                                                                                              object
#  75   Other.1                                                                                                                                                                                                                           float64
#  76   Anxiety Disorder (Generalized, Social, Phobia, etc).2                                                                                                                                                                             object
#  77   Mood Disorder (Depression, Bipolar Disorder, etc).2                                                                                                                                                                               object
#  78   Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2                                                                                                                                                                        object
#  79   Eating Disorder (Anorexia, Bulimia, etc).2                                                                                                                                                                                        object
#  80   Attention Deficit Hyperactivity Disorder.2                                                                                                                                                                                        object
#  81   Personality Disorder (Borderline, Antisocial, Paranoid, etc).2                                                                                                                                                                    object
#  82   Obsessive-Compulsive Disorder.2                                                                                                                                                                                                   object
#  83   Post-traumatic Stress Disorder.1                                                                                                                                                                                                  object
#  84   Stress Response Syndromes.2                                                                                                                                                                                                       object
#  85   Dissociative Disorder.2                                                                                                                                                                                                           object
#  86   Substance Use Disorder.2                                                                                                                                                                                                          object
#  87   Addictive Disorder.2                                                                                                                                                                                                              object
#  88   Other.2                                                                                                                                                                                                                           object
#  89   Have you had a mental health disorder in the past?                                                                                                                                                                                object
#  90   Have you ever sought treatment for a mental health disorder from a mental health professional?                                                                                                                                    int64
#  91   Do you have a family history of mental illness?                                                                                                                                                                                   object
#  92   If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*                                                                                                   object
#  93   If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*                                              object
#  94   Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?                                                     object
#  95   How willing would you be to share with friends and family that you have a mental illness?                                                                                                                                         int64
#  96   Would you be willing to bring up a physical health issue with a potential employer in an interview?                                                                                                                               object
#  97   Why or why not?                                                                                                                                                                                                                   object
#  98   Would you bring up your *mental* health with a potential employer in an interview?                                                                                                                                                object
#  99   Why or why not?.1                                                                                                                                                                                                                 object
#  100  Are you openly identified at work as a person with a mental health issue?                                                                                                                                                         int64
#  101  Has being identified as a person with a mental health issue affected your career?                                                                                                                                                 float64
#  102  How has it affected your career?                                                                                                                                                                                                  float64
#  103  If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?                                                                                                          int64
#  104  Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?                                                                                      object
#  105  Describe the circumstances of the badly handled or unsupportive response.                                                                                                                                                         object
#  106  Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?                                                                                          object
#  107  Describe the circumstances of the supportive or well handled response.                                                                                                                                                            float64
#  108  Overall, how well do you think the tech industry supports employees with mental health issues?                                                                                                                                    int64
#  109  Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.                                                                                                 object
#  110  If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.                                                                                            object
#  111  Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  int64
#  112  age                                                                                                                                                                                                                               int64
#  113  gender                                                                                                                                                                                                                            object
#  114  country                                                                                                                                                                                                                           object
#  115  What US state or territory do you *live* in?                                                                                                                                                                                      object
#  116  What is your race?                                                                                                                                                                                                                object
#  117  Other.3                                                                                                                                                                                                                           object
#  118  What country do you *work* in?                                                                                                                                                                                                    object
#  119  What US state or territory do you *work* in?                                                                                                                                                                                      object
# dtypes: float64(33), int64(9), object(78)
# memory usage: 168.9+ KB

# %%
print("Number of rows: {}, Number of columns: {}".format(surveyC.shape[0], surveyC.shape[1]))
# Out:
# Number of rows: 180, Number of columns: 120

# %%
#Check for NaN values
surveyC.isna().sum()
#surveyC.isna().mean() #Check what how much % NaN takes of the column
# Out:
# user                                                                                                                                                                                                                                  0
# self_employed                                                                                                                                                                                                                         0
# num_employees                                                                                                                                                                                                                        25
# is_tech_company                                                                                                                                                                                                                      25
# is_role_in_tech                                                                                                                                                                                                                      25
# mh_coverage                                                                                                                                                                                                                          25
# options_in_mh_coverage                                                                                                                                                                                                               47
# employer_mh_disc                                                                                                                                                                                                                     25
# employer_offer_mh_res                                                                                                                                                                                                                25
# mh_sa_anonimity                                                                                                                                                                                                                      25
# mh_leave_difficulty                                                                                                                                                                                                                  25
# coworker_comfort_reveal_ph_mh_disc                                                                                                                                                                                                   25
# supervisor_comfort_mh_disc                                                                                                                                                                                                           25
# employer_reveal_mh_disc                                                                                                                                                                                                              25
# employer_reveal_mh_disc_results                                                                                                                                                                                                     146
# coworker_comfort_mh_disc                                                                                                                                                                                                             25
# coworker_reveal_mh_disc                                                                                                                                                                                                              25
# coworker_reveal_mh_disc_results                                                                                                                                                                                                     127
# coworker_confine_mh_disc                                                                                                                                                                                                             26
# Describe the conversation your coworker had with you about their mental health (please do not use names).                                                                                                                           130
# Overall, how much importance does your employer place on physical health?                                                                                                                                                            25
# Overall, how much importance does your employer place on mental health?                                                                                                                                                              25
# Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?                                                                                                              155
# Do you know local or online resources to seek help for a mental health issue?                                                                                                                                                       155
# If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?                                                                                                        155
# If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?                                                                                                       165
# If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?                                                                                                              155
# If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?                                                                                                             155
# Do you believe your productivity is ever affected by a mental health issue?                                                                                                                                                         155
# If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?                                                                                                160
# *Do you have previous employers?*                                                                                                                                                                                                     0
# Was your employer primarily a tech company/organization?                                                                                                                                                                             45
# Have your previous employers provided mental health benefits?                                                                                                                                                                        45
# Were you aware of the options for mental health care provided by your previous employers?                                                                                                                                            45
# Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?                                                                                                    45
# Did your previous employers provide resources to learn more about mental health disorders and how to seek help?                                                                                                                      45
# Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?                                                                                         45
# Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?                                                                                                             45
# Would you have been willing to discuss your mental health with your direct supervisor(s)?                                                                                                                                            45
# Did you ever discuss your mental health with your previous employer?                                                                                                                                                                 45
# Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.                                                  155
# Would you have been willing to discuss your mental health with your coworkers at previous employers?                                                                                                                                 45
# Did you ever discuss your mental health with a previous coworker(s)?                                                                                                                                                                 47
# Describe the conversation you had with your previous coworkers about your mental health including their reactions.                                                                                                                  148
# Did you ever have a previous coworker discuss their or another coworker's mental health with you?                                                                                                                                    47
# Describe the conversation your coworker had with you about their mental health (please do not use names)..1                                                                                                                         152
# Overall, how much importance did your previous employer place on physical health?                                                                                                                                                    45
# Overall, how much importance did your previous employer place on mental health?                                                                                                                                                      45
# currently_has_mhd                                                                                                                                                                                                                     0
# Have you ever been *diagnosed* with a mental health disorder?                                                                                                                                                                       129
# Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                                                                                                 180
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                                                   180
# Psychotic Disorder (Schizophrenia, Schizoaffective, etc)                                                                                                                                                                            180
# Eating Disorder (Anorexia, Bulimia, etc)                                                                                                                                                                                            180
# Attention Deficit Hyperactivity Disorder                                                                                                                                                                                            180
# Personality Disorder (Borderline, Antisocial, Paranoid, etc)                                                                                                                                                                        180
# Obsessive-Compulsive Disorder                                                                                                                                                                                                       180
# Post-Traumatic Stress Disorder                                                                                                                                                                                                      180
# Stress Response Syndromes                                                                                                                                                                                                           180
# Dissociative Disorder                                                                                                                                                                                                               180
# Substance Use Disorder                                                                                                                                                                                                              180
# Addictive Disorder                                                                                                                                                                                                                  180
# Other                                                                                                                                                                                                                               180
# Anxiety Disorder (Generalized, Social, Phobia, etc).1                                                                                                                                                                               145
# Mood Disorder (Depression, Bipolar Disorder, etc).1                                                                                                                                                                                 156
# Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1                                                                                                                                                                          180
# Eating Disorder (Anorexia, Bulimia, etc).1                                                                                                                                                                                          179
# Attention Deficit Hyperactivity Disorder.1                                                                                                                                                                                          169
# Personality Disorder (Borderline, Antisocial, Paranoid, etc).1                                                                                                                                                                      173
# Obsessive-Compulsive Disorder.1                                                                                                                                                                                                     176
# Post-traumatic Stress Disorder                                                                                                                                                                                                      175
# Stress Response Syndromes.1                                                                                                                                                                                                         169
# Dissociative Disorder.1                                                                                                                                                                                                             178
# Substance Use Disorder.1                                                                                                                                                                                                            180
# Addictive Disorder.1                                                                                                                                                                                                                178
# Other.1                                                                                                                                                                                                                             180
# Anxiety Disorder (Generalized, Social, Phobia, etc).2                                                                                                                                                                               154
# Mood Disorder (Depression, Bipolar Disorder, etc).2                                                                                                                                                                                 146
# Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2                                                                                                                                                                          175
# Eating Disorder (Anorexia, Bulimia, etc).2                                                                                                                                                                                          176
# Attention Deficit Hyperactivity Disorder.2                                                                                                                                                                                          168
# Personality Disorder (Borderline, Antisocial, Paranoid, etc).2                                                                                                                                                                      174
# Obsessive-Compulsive Disorder.2                                                                                                                                                                                                     173
# Post-traumatic Stress Disorder.1                                                                                                                                                                                                    172
# Stress Response Syndromes.2                                                                                                                                                                                                         177
# Dissociative Disorder.2                                                                                                                                                                                                             179
# Substance Use Disorder.2                                                                                                                                                                                                            173
# Addictive Disorder.2                                                                                                                                                                                                                177
# Other.2                                                                                                                                                                                                                             179
# Have you had a mental health disorder in the past?                                                                                                                                                                                    4
# Have you ever sought treatment for a mental health disorder from a mental health professional?                                                                                                                                        0
# Do you have a family history of mental illness?                                                                                                                                                                                       0
# If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*                                                                                                       0
# If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*                                                  0
# Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?                                                        36
# How willing would you be to share with friends and family that you have a mental illness?                                                                                                                                             0
# Would you be willing to bring up a physical health issue with a potential employer in an interview?                                                                                                                                   0
# Why or why not?                                                                                                                                                                                                                      31
# Would you bring up your *mental* health with a potential employer in an interview?                                                                                                                                                    0
# Why or why not?.1                                                                                                                                                                                                                    29
# Are you openly identified at work as a person with a mental health issue?                                                                                                                                                             0
# Has being identified as a person with a mental health issue affected your career?                                                                                                                                                   155
# How has it affected your career?                                                                                                                                                                                                    165
# If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?                                                                                                              0
# Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?                                                                                          0
# Describe the circumstances of the badly handled or unsupportive response.                                                                                                                                                           131
# Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?                                                                                              0
# Describe the circumstances of the supportive or well handled response.                                                                                                                                                              180
# Overall, how well do you think the tech industry supports employees with mental health issues?                                                                                                                                        0
# Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.                                                                                                    44
# If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.                                                                                              108
# Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)      0
# age                                                                                                                                                                                                                                   0
# gender                                                                                                                                                                                                                                2
# country                                                                                                                                                                                                                               0
# What US state or territory do you *live* in?                                                                                                                                                                                        115
# What is your race?                                                                                                                                                                                                                  116
# Other.3                                                                                                                                                                                                                             179
# What country do you *work* in?                                                                                                                                                                                                        0
# What US state or territory do you *work* in?                                                                                                                                                                                        113
# dtype: int64

# %%
#Check for NaN values > 0
null_vals = surveyC.isnull().sum().sort_values().to_frame() #Returns a series, thus we need to make a df
null_vals = null_vals.loc[null_vals[0] != 0] #Find only the columns that have a null
null_vals
# Out:
#                                                       0
# Have you had a mental health disorder in the past?    4
# employer_mh_disc                                     25
# mh_coverage                                          25
# is_role_in_tech                                      25
# is_tech_company                                      25
# mh_sa_anonimity                                      25
# mh_leave_difficulty                                  25
# coworker_comfort_reveal_ph_mh_disc                   25
# supervisor_comfort_mh_disc                           25
# employer_reveal_mh_disc                              25
# num_employees                                        25
# Overall, how much importance does your employer...   25
# Overall, how much importance does your employer...   25
# coworker_comfort_mh_disc                             25
# employer_offer_mh_res                                25
# coworker_reveal_mh_disc                              25
# coworker_confine_mh_disc                             26
# Why or why not?.1                                    29
# Why or why not?                                      31
# Have your observations of how another individua...   36
# Briefly describe what you think the industry as...   44
# Would you have been willing to discuss your men...   45
# Was your employer primarily a tech company/orga...   45
# Have your previous employers provided mental he...   45
# Were you aware of the options for mental health...   45
# Did your previous employers ever formally discu...   45
# Overall, how much importance did your previous ...   45
# Overall, how much importance did your previous ...   45
# Did your previous employers provide resources t...   45
# Would you have been willing to discuss your men...   45
# Did you ever discuss your mental health with yo...   45
# Was your anonymity protected if you chose to ta...   45
# Would you have felt more comfortable talking to...   45
# options_in_mh_coverage                               47
# Did you ever have a previous coworker discuss t...   47
# Did you ever discuss your mental health with a ...   47
# If there is anything else you would like to tel...  108
# What US state or territory do you *work* in?        113
# What US state or territory do you *live* in?        115
# What is your race?                                  116
# coworker_reveal_mh_disc_results                     127
# Have you ever been *diagnosed* with a mental he...  129
# Describe the conversation your coworker had wit...  130
# Describe the circumstances of the badly handled...  131
# Anxiety Disorder (Generalized, Social, Phobia, ...  145
# employer_reveal_mh_disc_results                     146
# Mood Disorder (Depression, Bipolar Disorder, et...  146
# Describe the conversation you had with your pre...  148
# Describe the conversation your coworker had wit...  152
# Anxiety Disorder (Generalized, Social, Phobia, ...  154
# If you have been diagnosed or treated for a men...  155
# If you have been diagnosed or treated for a men...  155
# Do you believe your productivity is ever affect...  155
# If you have revealed a mental health disorder t...  155
# Describe the conversation you had with your pre...  155
# Has being identified as a person with a mental ...  155
# Do you know local or online resources to seek h...  155
# Do you have medical coverage (private insurance...  155
# Mood Disorder (Depression, Bipolar Disorder, et...  156
# If yes, what percentage of your work time (time...  160
# If you have revealed a mental health disorder t...  165
# How has it affected your career?                    165
# Attention Deficit Hyperactivity Disorder.2          168
# Stress Response Syndromes.1                         169
# Attention Deficit Hyperactivity Disorder.1          169
# Post-traumatic Stress Disorder.1                    172
# Personality Disorder (Borderline, Antisocial, P...  173
# Obsessive-Compulsive Disorder.2                     173
# Substance Use Disorder.2                            173
# Personality Disorder (Borderline, Antisocial, P...  174
# Psychotic Disorder (Schizophrenia, Schizoaffect...  175
# Post-traumatic Stress Disorder                      175
# Eating Disorder (Anorexia, Bulimia, etc).2          176
# Obsessive-Compulsive Disorder.1                     176
# Addictive Disorder.2                                177
# Stress Response Syndromes.2                         177
# Addictive Disorder.1                                178
# Dissociative Disorder.1                             178
# Dissociative Disorder.2                             179
# Eating Disorder (Anorexia, Bulimia, etc).1          179
# Other.3                                             179
# Other.2                                             179
# Describe the circumstances of the supportive or...  180
# Post-Traumatic Stress Disorder                      180
# Obsessive-Compulsive Disorder                       180
# Mood Disorder (Depression, Bipolar Disorder, etc)   180
# Psychotic Disorder (Schizophrenia, Schizoaffect...  180
# Eating Disorder (Anorexia, Bulimia, etc)            180
# Attention Deficit Hyperactivity Disorder            180
# Personality Disorder (Borderline, Antisocial, P...  180
# Stress Response Syndromes                           180
# Other.1                                             180
# Substance Use Disorder.1                            180
# Psychotic Disorder (Schizophrenia, Schizoaffect...  180
# Other                                               180
# Addictive Disorder                                  180
# Substance Use Disorder                              180
# Anxiety Disorder (Generalized, Social, Phobia, ...  180
# Dissociative Disorder                               180

# %%
print("Number of Columns that have more than 1 NaN is: {}".format(null_vals.shape[0]))
# Out:
# Number of Columns that have more than 1 NaN is: 100

# %% [markdown]
# ##### Find countries column

# %%
user_country = surveyC["country"].value_counts()

# %% [markdown]
# Lets plot the countries to have a better understanding
#
# https://stackoverflow.com/questions/43214978/seaborn-barplot-displaying-values/51535326#51535326

# %%
plt.figure(figsize=(8, 7))
sns_country = sns.barplot(x=user_country.values, y=user_country.index, palette=("Blues_d"))
plt.xlabel("Number of responds", fontsize=18)
plt.ylabel("Country", fontsize=18)

def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

show_values_on_bars(sns_country, "h", 0.3)

# %% [markdown]
# ## Data cleaning and visualzing

# %% [markdown]
# We saw that there were quite a few NANs, lets deal with them

# %% [markdown]
# - Change column titles

# %%
#Change column names for easier use
surveyC.rename(columns = {"#":"user",
                          "*Are you self-employed?*":"self_employed",
                          "What country do you *live* in?":"country",
                          "How many employees does your company or organization have?":"num_employees",
                          "Is your employer primarily a tech company/organization?":"is_tech_company",
                          "Is your primary role within your company related to tech/IT?":"is_role_in_tech",
                          "Does your employer provide mental health benefits as part of healthcare coverage?":"mh_coverage",
                          "Do you know the options for mental health care available under your employer-provided health coverage?":"options_in_mh_coverage",
                          "Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?":"employer_mh_disc",
                          "Does your employer offer resources to learn more about mental health disorders and options for seeking help?":"employer_offer_mh_res",
                          "Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?":"mh_sa_anonimity",
                          "If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?":"mh_leave_difficulty",
                          "Would you feel more comfortable talking to your coworkers about your physical health or your mental health?":"coworker_comfort_reveal_ph_mh_disc",
                          "Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?":"supervisor_comfort_mh_disc",
                          "Have you ever discussed your mental health with your employer?":"employer_reveal_mh_disc",
                          "Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.":"employer_reveal_mh_disc_results",
                          "Would you feel comfortable discussing a mental health issue with your coworkers?":"coworker_comfort_mh_disc",
                          "Have you ever discussed your mental health with coworkers?":"coworker_reveal_mh_disc",
                          "Describe the conversation with coworkers you had about your mental health including their reactions.":"coworker_reveal_mh_disc_results",
                          "Have you ever had a coworker discuss their or another coworker's mental health with you?":"coworker_confine_mh_disc",
    
                          "What is your gender?":"gender",
                          "What is your age?":"age",
                         "Do you *currently* have a mental health disorder?":"currently_has_mhd"}, 
               inplace=True)

# %% [markdown]
# - Change and encode mental health disorders

# %%
mh_list = [
    #["Anxiety Disorder (Generalized, Social, Phobia, etc)"]
    ["Eating Disorder (Anorexia, Bulimia, etc).1"]
]

def mh_encode(df, column):
    for row, col in df[column].iterrows():
        if df[column].isna():
            #df[column].replace(to_replace=column, value=0, inplace=True)
            print(True)
        else:
            #df[column].replace(to_replace=column, value=1, inplace=True)
            print(False)

#surveyC["Anxiety Disorder (Generalized, Social, Phobia, etc)"].isna()
#mh_encode(surveyC, ["Anxiety Disorder (Generalized, Social, Phobia, etc)"])
#if surveyC["Eating Disorder (Anorexia, Bulimia, etc).1"].isna():
for i in range(len(mh_list)):
    surveyC[i].fillna(0, inplace=True)
    surveyC[i].replace(to_replace=mh_list[0][0], value=1, inplace=True)
# Out:
# ----------------------------------------------------------
# KeyError                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                 Traceback (most recent call last)
# <ipython-input-59-f98cdae54888> in <module>
#      17 #if surveyC["Eating Disorder (Anorexia, Bulimia, etc).1"].isna():
#      18 for i in range(len(mh_list)):
# ---> 19     surveyC[i].fillna(0, inplace=True)
#      20     surveyC[i].replace(to_replace=mh_list[0][0], value=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0

# %%
mh_list[0][0]
# Out:
# 'Eating Disorder (Anorexia, Bulimia, etc).1'

# %% [markdown]
# - Change and encode gender column

# %%
#Make all values to lowercase and see the unique values
#surveyC["gender"].uniqe()
surveyC["gender"] = surveyC["gender"].str.lower()

# %%
#Categorize gender into: male, female, other
male_str = ["male", "mail", "m", "mostyl male", "mostly male", "cisgender male"]
fmale_str = ["female", "f", "woman", "she/her", "female, she/her"]

#Iterate through dataset and change the values
for (row, column) in surveyC.iterrows():
    if column["gender"] in male_str:
        surveyC["gender"].replace(to_replace=column["gender"],
                                              value=1, inplace=True)
    elif column["gender"] in fmale_str:
        surveyC["gender"].replace(to_replace=column["gender"],
                                               value=2, inplace=True)
    else: 
        surveyC["gender"].fillna(3, inplace=True)

# %%
surveyC["gender"].value_counts()
# Out:
# 1    116
# 2     62
# 3      2
# Name: gender, dtype: int64

# %%
#Example of a scenario to do a for loop, Series has a property of value_counts
#print(surveyC["What is your gender?"].value_counts().male)
#print(surveyC["What is your gender?"].value_counts().female)
#def count_str_occurences(df, column, values=[]):
#    total_instances = 0
#    if len(values) == 0 or None:
#        print("Please insert string values for 'values' in the following manner: values=['val1', 'val2']")
#    else:
#        for i in range(len(values)):
#            total_instances += df[column].value_counts().values[i]
#            print("For '{}', there's {} instances".format(values[i], df[column].value_counts().values[i]))
#    print("-"*20)
#    print("Total instances:", total_instances)
            
#count_str_occurences(surveyC, "gender", values=['male', 'female', 'other'])

# %%
#Plot age and gender in each country
#plt.figure(figsize=(12, 8))
#x = sns.barplot(x="country",
#                y="age",
#                hue="gender",
#                data=surveyC)

#If x and y axes are shifted
#for item in x.get_xticklabels():
#    item.set_rotation(90)

# %%
#surveyC["Other.2"].unique()

# %%
#Check how many times "Autism Spectrum Disorder" appears in the df
#(surveyC["Other.2"].values == "Autism Spectrum Disorder").sum()

# %%
#Let's check if we can insert Autism disorder to the right column
#surveyC.loc[surveyC["Other.2"] == "Autism Spectrum Disorder"]

# %%
#User 83 has benn diagnosed with a autism disorder yet there isn't any 
#appropriate column for it, so let's make one: "Autism spectrum disorder"

# %%
#Check which user inserted Latino, there should be a race column 
#survey.index[survey["Other.3"]== "Latino "] #Get only the index
#surveyC.loc[survey["Other.3"] == "Latino "] #Gets more information about the user

# %%
#Check what user 39's value for race
#survey["What is your race?"][survey.index[39]]

# %%
#Fill in "Latino" value for user 39 in race column
#surveyC.loc[[39], "What is your race?"] = "Latino"

# %%
#Check how many times "Latino " appears in the df (Note: it has whitespace)
#(surveyC["Other.3"].values == "Latino ").sum()

# %% [markdown]
# ## Encoding data

# %% [markdown]
# ## Answering questions

# %% [markdown]
# - Are people who are self imployed have more mental disorders?

# %%
#Have a look at the values and dtype
surveyC["self_employed"].value_counts()

#How do we know what is yes or no? Assuming we don't have access to the ones 
#that made the survey, we can infer by looking at the column "How many employees does your company or organization have?"
#If they didn't put any value, it means that they're most likely self employed
#Thus, 1 = yes, 0 = no
#num_na = surveyC["How many employees does your company or organization have?"].isna().sum()
#num_na

#Check answers
surveyC["currently_has_mhd"].value_counts()
# Out:
# No            58
# Yes           51
# Possibly      47
# Don't Know    24
# Name: currently_has_mhd, dtype: int64

# %%
#Save the copy
#surveyC.to_csv("Dataset/Mental_Health_in_Tech_2020_OSMI-COPY.csv:)
