# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

#Uses Jupyter's own backend to plot
# %matplotlib inline

# %% [markdown]
# **Show all rows**

# %%
#Show all rows and columns
pd.set_option("max_rows", None)
pd.set_option("max_columns", None)

# %% [markdown]
# #To do - questions to answer
#
# Get to know the dataset
#  - ~~Initial visualization~~
#  - ~~Change column titles~~
#
# Data cleaning
#  - Change all NAN to numerical values
#      - Number of employees
#      - Is your employer primarily a tech company/organization?
#      - Gender
#          - ~~Change gender to male, female, other~~
#          - ~~Encode gender~~
#          - ~~Visualize % of gender and age in each country~~
#      - Mental health disorder columns
#          - ~~Anxiety Disorder (Generalized, Social, Phobia, etc)~~
#          - ~~Mood Disorder (Depression, Bipolar Disorder, etc)~~
#          - ~~Psychotic Disorder (Schizophrenia, Schizoaffective, etc)~~
#          - ~~Eating Disorder (Anorexia, Bulimia, etc)~~
#          - ~~Attention Deficit Hyperactivity Disorder~~
#          - ~~Personality Disorder (Borderline, Antisocial, Paranoid, etc)~~
#          - ~~Obsessive-Compulsive Disorder~~
#          - ~~Post-Traumatic Stress Disorder~~
#          - ~~Stress Response Syndromes~~
#          - ~~Dissociative Disorder~~
#          - ~~Substance Use Disorder~~
#          - ~~Addictive Disorder~~
#          - Make columns:
#              - "If possibly, what disorder(s) do you believe you have?"
#              - "If so, what disorder(s) were you diagnosed with?"
#              - "Put Disorders into corresponding columns"
#      - Race
#          - ~~Change NaN to "I prefer not to answer"~~
#          - ~~Other.3~~
#
#
# Question to answer
#  - How likely is someone going to look for mental health treatment given a set of features
#      - Our y is "sought_mh_treatment"
#      - Our X is the list of eature
#
#  - Are people who are self imployed have more mental disorders?
#      - Look how many self employed/employee there are
#      - Compare how many of them **currently** have mental disorders
#  - Have you ever been diagnosed with mental health disorder
#      - If possible, what disorders do you believe you have?
#          - Find out which disorders answers belong to this question
#      - If so, what disorders were you diagnosed with?
#          - Find out which disorders answers belong to this question
#  - Do you currently have a mental disorder?
#  - Have you had a mental health disorder in the past?

# %% [markdown]
# # 1. Data exploration

# %%
#Read original CSV, make a copy of it
surveyO = pd.read_csv("Dataset/Mental_Health_in_Tech_2020_OSMI.csv")
surveyC1 = surveyO.copy() #Make changes here instead of the original df

# %%
surveyC1.head(5)
# Out:
#    num_employees  is_comp_role_in_tech  employer_mh_coverage  \
# 1           1001                   1.0                     2
# 2            501                   1.0                     0
# 3              6                   1.0                     1
# 4             26                   1.0                     2
# 5            501                   1.0                     0
#
#    employer_options_in_mh_coverage employer_mh_disc employer_offer_mh_res  \
# 1                                0              Yes                   Yes
# 2                                0     I don't know                   Yes
# 3                                0               No                    No
# 4                                1     I don't know          I don't know
# 5                                0               No                   Yes
#
#   employer_mh_sa_anonimity employer_mh_leave_difficulty  \
# 1             I don't know                    Very easy
# 2             I don't know                Somewhat easy
# 3             I don't know                    Very easy
# 4             I don't know                Somewhat easy
# 5                      Yes                    Difficult
#
#   coworker_comfort_reveal_ph_mh_disc supervisor_comfort_mh_disc  \
# 1                    Physical health                        Yes
# 2                      Mental health                      Maybe
# 3                    Physical health                         No
# 4                    Physical health                        Yes
# 5                    Physical health                         No
#
#    employer_reveal_mh_disc coworker_comfort_mh_disc  coworker_reveal_mh_disc  \
# 1                      0.0                    Maybe                      0.0
# 2                      0.0                      Yes                      1.0
# 3                      0.0                       No                      1.0
# 4                      1.0                    Maybe                      1.0
# 5                      0.0                       No                      0.0
#
#    coworker_confine_mh_disc  employer_ph_importance  employer_mh_importance  \
# 1                       0.0                     4.0                     4.0
# 2                       0.0                     8.0                     8.0
# 3                       1.0                     4.0                     2.0
# 4                       1.0                     8.0                     8.0
# 5                       0.0                     8.0                     6.0
#
#    prev_employer prev_employer_is_tech_company prev_employer_mh_coverage  \
# 1              1                           Yes                  Some did
# 2              1                           Yes              No, none did
# 3              1                            No                  Some did
# 4              1                            No                  Some did
# 5              1                           Yes              No, none did
#
#   prev_employer_options_in_mh_coverage prev_employer_mh_disc  \
# 1                  N/A (was not aware)              None did
# 2                   N/A (none offered)              None did
# 3                  I was aware of some     Yes, they all did
# 4                  I was aware of some              Some did
# 5                  N/A (was not aware)              None did
#
#   prev_employer_offer_mh_res prev_employer_mh_sa_anonimity  \
# 1                   Some did                            No
# 2                   None did                  I don't know
# 3                   Some did                            No
# 4                   Some did                  I don't know
# 5                   None did                            No
#
#   prev_employer_comfort_reveal_ph_mh_disc  \
# 1                         Physical health
# 2                         Physical health
# 3          Same level of comfort for each
# 4                         Physical health
# 5                         Physical health
#
#        prev_supervisor_comfort_mh_disc  prev_employer_reveal_mh_disc  \
# 1  No, none of my previous supervisors                           0.0
# 2  No, none of my previous supervisors                           0.0
# 3  No, none of my previous supervisors                           0.0
# 4      Some of my previous supervisors                           1.0
# 5      Some of my previous supervisors                           0.0
#
#           prev_coworker_comfort_mh_disc  prev_coworker_mh_desc  \
# 1      At some of my previous employers                    1.0
# 2  No, at none of my previous employers                    0.0
# 3  No, at none of my previous employers                    0.0
# 4      At some of my previous employers                    1.0
# 5      At some of my previous employers                    NaN
#
#    prev_coworker_confine_mh_disc  prev_employer_ph_importance  \
# 1                            0.0                          1.0
# 2                            0.0                          5.0
# 3                            0.0                          0.0
# 4                            1.0                         10.0
# 5                            NaN                          8.0
#
#    prev_employer_mh_importance currently_have_mh diagnosed_mh  \
# 1                          0.0          Possibly          NaN
# 2                          5.0        Don't Know          NaN
# 3                          0.0          Possibly          NaN
# 4                          9.0               Yes          Yes
# 5                          6.0          Possibly          NaN
#
#   Anxiety Disorder (Generalized, Social, Phobia, etc).1  \
# 1  Anxiety Disorder (Generalized, Social, Phobia,...
# 2                                                NaN
# 3  Anxiety Disorder (Generalized, Social, Phobia,...
# 4                                                NaN
# 5  Anxiety Disorder (Generalized, Social, Phobia,...
#
#   Mood Disorder (Depression, Bipolar Disorder, etc).1  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Mood Disorder (Depression, Bipolar Disorder, etc)
#
#    Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Eating Disorder (Anorexia, Bulimia, etc).1  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
#
#   Attention Deficit Hyperactivity Disorder.1  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
#
#   Personality Disorder (Borderline, Antisocial, Paranoid, etc).1  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Obsessive-Compulsive Disorder.1 Post-traumatic Stress Disorder.1  \
# 1                             NaN   Post-traumatic Stress Disorder
# 2                             NaN                              NaN
# 3                             NaN   Post-traumatic Stress Disorder
# 4                             NaN                              NaN
# 5   Obsessive-Compulsive Disorder                              NaN
#
#   Stress Response Syndromes.1 Dissociative Disorder.1  \
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN   Dissociative Disorder
#
#    Substance Use Disorder.1 Addictive Disorder.1  Other.1  \
# 1                       NaN                  NaN      NaN
# 2                       NaN                  NaN      NaN
# 3                       NaN                  NaN      NaN
# 4                       NaN                  NaN      NaN
# 5                       NaN                  NaN      NaN
#
#   Anxiety Disorder (Generalized, Social, Phobia, etc).2  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Anxiety Disorder (Generalized, Social, Phobia,...
# 5                                                NaN
#
#   Mood Disorder (Depression, Bipolar Disorder, etc).2  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Mood Disorder (Depression, Bipolar Disorder, etc)
# 5                                                NaN
#
#   Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Eating Disorder (Anorexia, Bulimia, etc).2  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
#
#   Attention Deficit Hyperactivity Disorder.2  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4   Attention Deficit Hyperactivity Disorder
# 5                                        NaN
#
#   Personality Disorder (Borderline, Antisocial, Paranoid, etc).2  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Obsessive-Compulsive Disorder.2 Post-traumatic Stress Disorder.2  \
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4   Obsessive-Compulsive Disorder   Post-traumatic Stress Disorder
# 5                             NaN                              NaN
#
#   Stress Response Syndromes.2 Dissociative Disorder.2  \
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN                     NaN
#
#   Substance Use Disorder.2 Addictive Disorder.2 Other.2   past_mh  \
# 1                      NaN                  NaN     NaN  Possibly
# 2                      NaN                  NaN     NaN        No
# 3                      NaN                  NaN     NaN        No
# 4   Substance Use Disorder                  NaN     NaN       Yes
# 5                      NaN                  NaN     NaN        No
#
#    sought_mh_treatment mh_family_history mh_with_treatment_impact_on_work  \
# 1                    0               Yes                        Sometimes
# 2                    0                No                            Never
# 3                    0      I don't know                           Rarely
# 4                    1               Yes                        Sometimes
# 5                    1                No                            Often
#
#   mh_with_no_treatment_impact_on_work  \
# 1                           Sometimes
# 2                               Never
# 3                           Sometimes
# 4                               Often
# 5                               Often
#
#   others_mh_reveal_impact_on_mh_self_reveal  friends_fam_mh_reveal  \
# 1                                     Maybe                      3
# 2                                       NaN                      7
# 3                                       Yes                      0
# 4                                        No                      9
# 5                                       Yes                      7
#
#   future_employer_ph_reveal future_employer_mh_reveal  identified_mh_at_work  \
# 1                       Yes                        No                      0
# 2                        No                        No                      0
# 3                        No                        No                      0
# 4                     Maybe                        No                      0
# 5                     Maybe                        No                      0
#
#    identified_mh_at_work_has_effected  identified_mh_at_work_how_effected  \
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
# 5                                 NaN                                 NaN
#
#    if_coworker_knew_of_my_mh_results mh_bad_response_at_work  \
# 1                                  3         Yes, I observed
# 2                                  6                      No
# 3                                  0          Maybe/Not sure
# 4                                  7                      No
# 5                                  3                      No
#
#   mh_positive_response_at_work_desc  tech_industry_mh_support  \
# 1                   Yes, I observed                         4
# 2                    Maybe/Not sure                         3
# 3                                No                         3
# 4                   Yes, I observed                         4
# 5                Yes, I experienced                         3
#
#    survey_creators_comfort_reveal  age  gender              country_live  \
# 1                               1   26    male  United States of America
# 2                               0   32    Male                     India
# 3                               1   34    Male  United States of America
# 4                               1   44  female  United States of America
# 5                               0   33       M                     India
#
#                          race Other.3              country_work
# 1                       White     NaN  United States of America
# 2                         NaN     NaN                     India
# 3  More than one of the above     NaN  United States of America
# 4                       White     NaN  United States of America
# 5                         NaN     NaN                     India

# %%
surveyC1["Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions."].value_counts()
# Out:
# Yes                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# I was asked if I wished to speak with HR about it. It was not a pleasant experience                                                                                                                                                                                                                                                                                                                                                                               1
# I was having a hard time because of the work pressure and my employer gave me some days off                                                                                                                                                                                                                                                                                                                                                                       1
# Burnout                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# She saw that I was not feeling well and asked me about it. In this moment I was so emotional that I had to talk about it with her.                                                                                                                                                                                                                                                                                                                                1
# Very depressed, was booked off for 1 week, recharged batteries and continued doing my work                                                                                                                                                                                                                                                                                                                                                                        1
# Prefer not to answer                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Explained problem and agreed I should see doctor.                                                                                                                                                                                                                                                                                                                                                                                                                 1
# I have ADD and worked with formal employers on how to best handle some of the issues at that time.                                                                                                                                                                                                                                                                                                                                                                1
# In my last job, it only finally came up on the day I was fired. They were supportive, having obviously recognized it, but the position was a pressure cooker and it was too late anyway. In the job before that, I went to see one of the HR managers for a referral after most of a week just unable to get to work, and she handed me list of counselors but that was the end of everything. Other signs like anger management issues had been long ignored.    1
# i am suffering from stress                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# More or less the same as my current employers (see question 2.p.)                                                                                                                                                                                                                                                                                                                                                                                                 1
# It was when I found out I had an anxiety disorder mixed in with depression and I had to let me boss know at my retail job why my work was starting to faulter.                                                                                                                                                                                                                                                                                                    1
# i dont know                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Explaining agoraphobia and the effects on my performance                                                                                                                                                                                                                                                                                                                                                                                                          1
# Varied between employees. Notified all of anxiety and panic attacks. Some supported, others just ignored it                                                                                                                                                                                                                                                                                                                                                       1
# I only had the opportunity to talk about my feelings. No actions were taken.                                                                                                                                                                                                                                                                                                                                                                                      1
# I was making silly errors in the work and it was because my boss was bullying me continuously and I was suppressed and stressed. Then in 1-1 with him I discussed about the same. He reacted wisely and asked to take my own time and relax. But at the same time he continued doing same things. So I has to put resignation there.                                                                                                                              1
# I informed my manager of a mental health issue and the need for regular, frequent, couseling sessions.  He was supportive.                                                                                                                                                                                                                                                                                                                                        1
# dont remember                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# I had severe insomnia and mania and required hospitalization. My supervisor suggested I take the needed time off before I did! She was wonderful and very supportive. When I came back, she continued to show she cared.                                                                                                                                                                                                                                          1
# das                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# I spoke, at several previous jobs, about burnout, it's effects on my ability to deliver.  And discussed potential short and longer term solutions.\n\nAt one previous job, when a coworker died unexpectedly, grief counselors were made available.                                                                                                                                                                                                               1
# I was very overwhelmed and my manager listened.                                                                                                                                                                                                                                                                                                                                                                                                                   1
# It was a show of false compassion. Nothing was done to help or even  encourage pursuing help.                                                                                                                                                                                                                                                                                                                                                                     1
# Name: Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions., dtype: int64

# %%
print("Number of rows: {}, Number of columns: {}".format(surveyC1.shape[0], surveyC1.shape[1]))
# Out:
# Number of rows: 180, Number of columns: 120

# %%
#Check for NaN values > 0
null_vals = surveyC1.isnull().sum().sort_values().to_frame() #Returns a series, thus we need to make a df
null_vals = null_vals.loc[null_vals[0] != 0] #Find only the columns that have a null
null_vals
# Out:
#                                                       0
# What is your gender?                                  2
# Have you had a mental health disorder in the past?    4
# Overall, how much importance does your employer...   25
# Overall, how much importance does your employer...   25
# Have you ever discussed your mental health with...   25
# Has your employer ever formally discussed menta...   25
# Does your employer provide mental health benefi...   25
# Is your primary role within your company relate...   25
# How many employees does your company or organiz...   25
# Is your anonymity protected if you choose to ta...   25
# Is your employer primarily a tech company/organ...   25
# Would you feel more comfortable talking to your...   25
# Would you feel comfortable discussing a mental ...   25
# Have you ever discussed your mental health with...   25
# Would you feel comfortable discussing a mental ...   25
# If a mental health issue prompted you to reques...   25
# Does your employer offer resources to learn mor...   25
# Have you ever had a coworker discuss their or a...   26
# Why or why not?.1                                    29
# Why or why not?                                      31
# Have your observations of how another individua...   36
# Briefly describe what you think the industry as...   44
# Overall, how much importance did your previous ...   45
# Overall, how much importance did your previous ...   45
# Did you ever discuss your mental health with yo...   45
# Would you have been willing to discuss your men...   45
# Would you have been willing to discuss your men...   45
# Was your anonymity protected if you chose to ta...   45
# Did your previous employers provide resources t...   45
# Did your previous employers ever formally discu...   45
# Were you aware of the options for mental health...   45
# Have your previous employers provided mental he...   45
# Was your employer primarily a tech company/orga...   45
# Would you have felt more comfortable talking to...   45
# Did you ever discuss your mental health with a ...   47
# Do you know the options for mental health care ...   47
# Did you ever have a previous coworker discuss t...   47
# If there is anything else you would like to tel...  108
# What US state or territory do you *work* in?        113
# What US state or territory do you *live* in?        115
# What is your race?                                  116
# Describe the conversation with coworkers you ha...  127
# Have you ever been *diagnosed* with a mental he...  129
# Describe the conversation your coworker had wit...  130
# Describe the circumstances of the badly handled...  131
# Anxiety Disorder (Generalized, Social, Phobia, ...  145
# Describe the conversation you had with your emp...  146
# Mood Disorder (Depression, Bipolar Disorder, et...  146
# Describe the conversation you had with your pre...  148
# Describe the conversation your coworker had wit...  152
# Anxiety Disorder (Generalized, Social, Phobia, ...  154
# If you have been diagnosed or treated for a men...  155
# If you have been diagnosed or treated for a men...  155
# Do you believe your productivity is ever affect...  155
# If you have revealed a mental health disorder t...  155
# Describe the conversation you had with your pre...  155
# Has being identified as a person with a mental ...  155
# Do you know local or online resources to seek h...  155
# Do you have medical coverage (private insurance...  155
# Mood Disorder (Depression, Bipolar Disorder, et...  156
# If yes, what percentage of your work time (time...  160
# If you have revealed a mental health disorder t...  165
# How has it affected your career?                    165
# Attention Deficit Hyperactivity Disorder.2          168
# Stress Response Syndromes.1                         169
# Attention Deficit Hyperactivity Disorder.1          169
# Post-traumatic Stress Disorder.1                    172
# Personality Disorder (Borderline, Antisocial, P...  173
# Obsessive-Compulsive Disorder.2                     173
# Substance Use Disorder.2                            173
# Personality Disorder (Borderline, Antisocial, P...  174
# Psychotic Disorder (Schizophrenia, Schizoaffect...  175
# Post-traumatic Stress Disorder                      175
# Eating Disorder (Anorexia, Bulimia, etc).2          176
# Obsessive-Compulsive Disorder.1                     176
# Addictive Disorder.2                                177
# Stress Response Syndromes.2                         177
# Addictive Disorder.1                                178
# Dissociative Disorder.1                             178
# Dissociative Disorder.2                             179
# Eating Disorder (Anorexia, Bulimia, etc).1          179
# Other.3                                             179
# Other.2                                             179
# Describe the circumstances of the supportive or...  180
# Post-Traumatic Stress Disorder                      180
# Obsessive-Compulsive Disorder                       180
# Mood Disorder (Depression, Bipolar Disorder, etc)   180
# Psychotic Disorder (Schizophrenia, Schizoaffect...  180
# Eating Disorder (Anorexia, Bulimia, etc)            180
# Attention Deficit Hyperactivity Disorder            180
# Personality Disorder (Borderline, Antisocial, P...  180
# Stress Response Syndromes                           180
# Other.1                                             180
# Substance Use Disorder.1                            180
# Psychotic Disorder (Schizophrenia, Schizoaffect...  180
# Other                                               180
# Addictive Disorder                                  180
# Substance Use Disorder                              180
# Anxiety Disorder (Generalized, Social, Phobia, ...  180
# Dissociative Disorder                               180

# %%
print("Number of Columns that have more than 1 NaN is: {}".format(null_vals.shape[0]))
# Out:
# Number of Columns that have more than 1 NaN is: 100

# %%
#Missing values visualization
plt.figure(figsize=(20, 10))

heatmap_survey = surveyC1.transpose()
sns.heatmap(data = heatmap_survey.isnull());

# %% [markdown]
# # 2. Data cleaning

# %% [markdown]
# The following will be dealt separately:
# - Employer type and role
# - Age
# - Gender
# - Country of employment
# - Work position

# %%
#A function to help us clean the data on preprocessing step
def evaluate_df_cols(df):
    for index, col in enumerate(df):
        print()
        print("Index position: {}, Column name: {}".format(index, col))
        print()
        
        unique_vals = df[col].unique()
        print("Unique values:\n", unique_vals)
        print()
        print("Frequency of values and data type:\n{}".format(df[col].value_counts()))
        print()
        print("Total value count in column: {}/{}".format(df[col].value_counts().sum(), len(df)))
        print()
        
        nans = df[col].isna().sum()
        print("Total NaNs in column: {}".format(nans))
        print()
        print("-"*50)

# %% [markdown]
# ### 2.a Dropping the following columns:
# - User ID
# - Mental health disorder(mhd) columns
#     - There are 3 types: name_of_mhd, name_of_mhd.1, and name_of_mhd.2. We'll be dropping columns relating to "name_of_mhd" becuase none of the users answered
# - Open ended questions
# - Any questions related to self-employed users, because it doesn't relate to the majority of other users

# %%
#Dropping mental health disorder
#If we check the documentation, we can see the questions they're related to: 

#"What disorder(s) have you been diagnosed with?" = "name_of_mhd"
#"If possibly, what disorder(s) do you believe you have?" = "name_of_mhd.1"
#"If so, what disorder(s) were you diagnosed with?" = "name_of_mhd.2"
mhd_cols = [
    "Anxiety Disorder (Generalized, Social, Phobia, etc)",
    "Mood Disorder (Depression, Bipolar Disorder, etc)",
    "Psychotic Disorder (Schizophrenia, Schizoaffective, etc)",
    "Eating Disorder (Anorexia, Bulimia, etc)",
    "Attention Deficit Hyperactivity Disorder",
    "Personality Disorder (Borderline, Antisocial, Paranoid, etc)",
    "Obsessive-Compulsive Disorder",
    "Post-Traumatic Stress Disorder",
    "Stress Response Syndromes",
    "Dissociative Disorder",
    "Substance Use Disorder",
    "Addictive Disorder",
    "Other"
]

#Dropping open ended questions
open_ended_ques_cols = [
    "Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.",
    "Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.",
    "Describe the conversation with coworkers you had about your mental health including their reactions.",
    "Describe the conversation you had with your previous coworkers about your mental health including their reactions.",
    "Describe the conversation your coworker had with you about their mental health (please do not use names).",
    "Describe the conversation your coworker had with you about their mental health (please do not use names)..1",
    "Why or why not?",
    "Why or why not?.1",
    "Describe the circumstances of the badly handled or unsupportive response.",
    "Describe the circumstances of the supportive or well handled response.",
    "Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.",
    "If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so."
]

#Dropping questions related to self-employed users
self_emp_ques_cols = [
    "*Are you self-employed?*",
    "Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?",
    "Do you know local or online resources to seek help for a mental health issue?", 
    "If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?",
    "If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?",
    "If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?",
    "If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?",
    "Do you believe your productivity is ever affected by a mental health issue?",
    "If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?"
]

irrelevant_cols =[
    "#",
    "Other",
    "What US state or territory do you *work* in?",
    "What US state or territory do you *live* in?",
]
surveyC1 = surveyC1.drop(mhd_cols + open_ended_ques_cols + self_emp_ques_cols + irrelevant_cols, axis=1)

#Dropping (rows) users who are self-employed
surveyC1 = surveyC1.drop(range(0, 25), axis=0)

#Reset survey index values 
surveyC1.index = np.arange(1, len(surveyC1) + 1)

# %% [markdown]
# ### 2.b Renaming columns

# %%
#Change column names for easier use
surveyC1.rename(columns = {
                          "How many employees does your company or organization have?":"num_employees",
                          "Is your employer primarily a tech company/organization?":"is_tech_company",
                          "Is your primary role within your company related to tech/IT?":"is_role_in_tech",
                          "Does your employer provide mental health benefits as part of healthcare coverage?":"employer_mh_coverage",
                          "Do you know the options for mental health care available under your employer-provided health coverage?":"employer_options_in_mh_coverage",
                          "Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?":"employer_mh_disc",
                          "Does your employer offer resources to learn more about mental health disorders and options for seeking help?":"employer_offer_mh_res",
                          "Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?":"employer_mh_sa_anonimity",
                          "If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?":"employer_mh_leave_difficulty",
                          "Would you feel more comfortable talking to your coworkers about your physical health or your mental health?":"coworker_comfort_reveal_ph_mh_disc",
                          "Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?":"supervisor_comfort_mh_disc",
                          "Have you ever discussed your mental health with your employer?":"employer_reveal_mh_disc",
                          "Would you feel comfortable discussing a mental health issue with your coworkers?":"coworker_comfort_mh_disc",
                          "Have you ever discussed your mental health with coworkers?":"coworker_reveal_mh_disc",
                          "Have you ever had a coworker discuss their or another coworker's mental health with you?":"coworker_confine_mh_disc",
                          "Overall, how much importance does your employer place on physical health?":"employer_ph_importance",
                          "Overall, how much importance does your employer place on mental health?":"employer_mh_importance",
                          "If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?":"self_employed_mh_reveal_to_clients",
                          "*Do you have previous employers?*":"prev_employer",
                          "Was your employer primarily a tech company/organization?":"prev_employer_is_tech_company",
                          "Have your previous employers provided mental health benefits?":"prev_employer_mh_coverage",
                          "Were you aware of the options for mental health care provided by your previous employers?":"prev_employer_options_in_mh_coverage",
                          "Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?":"prev_employer_mh_disc",
                          "Did your previous employers provide resources to learn more about mental health disorders and how to seek help?":"prev_employer_offer_mh_res",
                          "Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?":"prev_employer_mh_sa_anonimity",
                          "Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?":"prev_employer_comfort_reveal_ph_mh_disc",
                          "Would you have been willing to discuss your mental health with your direct supervisor(s)?":"prev_supervisor_comfort_mh_disc",
                          "Did you ever discuss your mental health with your previous employer?":"prev_employer_reveal_mh_disc",
                          "Would you have been willing to discuss your mental health with your coworkers at previous employers?":"prev_coworker_comfort_mh_disc",
                          "Did you ever discuss your mental health with a previous coworker(s)?":"prev_coworker_mh_desc",
                          "Did you ever have a previous coworker discuss their or another coworker's mental health with you?":"prev_coworker_confine_mh_disc",
                          "Overall, how much importance did your previous employer place on physical health?":"prev_employer_ph_importance",
                          "Overall, how much importance did your previous employer place on mental health?":"prev_employer_mh_importance",
                          "Do you *currently* have a mental health disorder?":"currently_have_mh",
                          "Have you ever been *diagnosed* with a mental health disorder?":"diagnosed_mh",
                          "Post-traumatic Stress Disorder.1":"Post-traumatic Stress Disorder.2",
                          "Post-traumatic Stress Disorder":"Post-traumatic Stress Disorder.1",
                          "Have you had a mental health disorder in the past?":"past_mh",
                          "Have you ever sought treatment for a mental health disorder from a mental health professional?":"sought_mh_treatment",
                          "Do you have a family history of mental illness?":"mh_family_history",
                          "If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*":"mh_with_treatment_impact_on_work",
                          "If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*":"mh_with_no_treatment_impact_on_work",
                          "Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?":"others_mh_reveal_impact_on_mh_self_reveal",
                          "How willing would you be to share with friends and family that you have a mental illness?":"friends_fam_mh_reveal",
                          "Would you be willing to bring up a physical health issue with a potential employer in an interview?":"future_employer_ph_reveal",
                          "Would you bring up your *mental* health with a potential employer in an interview?":"future_employer_mh_reveal",
                          "Are you openly identified at work as a person with a mental health issue?":"identified_mh_at_work",
                          "Has being identified as a person with a mental health issue affected your career?":"identified_mh_at_work_has_effected",
                          "How has it affected your career?":"identified_mh_at_work_how_effected",
                          "If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?":"if_coworker_knew_of_my_mh_results",
                          "Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?":"mh_bad_response_at_work",
                          "Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?":"mh_positive_response_at_work_desc",
                          "Overall, how well do you think the tech industry supports employees with mental health issues?":"tech_industry_mh_support",
                          "Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)":"survey_creators_comfort_reveal",
                          "What is your age?":"age",
                          "What is your gender?":"gender",
                          "What country do you *live* in?":"country_live",
                          "What is your race?":"race",
                          "What country do you *work* in?":"country_work"
                         },
               inplace=True)

# %% [markdown]
# ## 2.c Preprocessing

# %% [markdown]
# - We'll change catagrical attributes to numerical values for ease of use during classification step

# %%
evaluate_df_cols(surveyC1)
# Out:
# Index position: 0, Column name: num_employees
#
# Unique values:
#  [1001  501    6   26  101    1]
#
# Frequency of values and data type:
# 1001    65
# 26      25
# 101     21
# 501     19
# 6       10
# 1        1
# Name: num_employees, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 1, Column name: is_comp_role_in_tech
#
# Unique values:
#  [1.]
#
# Frequency of values and data type:
# 1.0    141
# Name: is_comp_role_in_tech, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 2, Column name: employer_mh_coverage
#
# Unique values:
#  [2 0 1 'Not eligible for coverage / NA']
#
# Frequency of values and data type:
# 2                                 62
# 1                                 42
# 0                                 31
# Not eligible for coverage / NA     6
# Name: employer_mh_coverage, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 3, Column name: employer_options_in_mh_coverage
#
# Unique values:
#  [ 0  1 -1]
#
# Frequency of values and data type:
#  0    74
#  1    45
# -1    22
# Name: employer_options_in_mh_coverage, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 4, Column name: employer_mh_disc
#
# Unique values:
#  ['Yes' "I don't know" 'No']
#
# Frequency of values and data type:
# No              69
# Yes             60
# I don't know    12
# Name: employer_mh_disc, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 5, Column name: employer_offer_mh_res
#
# Unique values:
#  ['Yes' 'No' "I don't know"]
#
# Frequency of values and data type:
# No              61
# Yes             51
# I don't know    29
# Name: employer_offer_mh_res, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 6, Column name: employer_mh_sa_anonimity
#
# Unique values:
#  ["I don't know" 'Yes' 'No']
#
# Frequency of values and data type:
# I don't know    76
# Yes             50
# No              15
# Name: employer_mh_sa_anonimity, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 7, Column name: employer_mh_leave_difficulty
#
# Unique values:
#  ['Very easy' 'Somewhat easy' 'Difficult' 'Neither easy nor difficult'
#  'Somewhat difficult' "I don't know"]
#
# Frequency of values and data type:
# Somewhat easy                 40
# Very easy                     29
# Difficult                     22
# I don't know                  17
# Neither easy nor difficult    17
# Somewhat difficult            16
# Name: employer_mh_leave_difficulty, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 8, Column name: coworker_comfort_reveal_ph_mh_disc
#
# Unique values:
#  ['Physical health' 'Mental health' 'Same level of comfort for each']
#
# Frequency of values and data type:
# Physical health                   103
# Same level of comfort for each     33
# Mental health                       5
# Name: coworker_comfort_reveal_ph_mh_disc, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 9, Column name: supervisor_comfort_mh_disc
#
# Unique values:
#  ['Yes' 'Maybe' 'No']
#
# Frequency of values and data type:
# No       55
# Maybe    47
# Yes      39
# Name: supervisor_comfort_mh_disc, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 10, Column name: employer_reveal_mh_disc
#
# Unique values:
#  [0. 1.]
#
# Frequency of values and data type:
# 0.0    103
# 1.0     38
# Name: employer_reveal_mh_disc, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 11, Column name: coworker_comfort_mh_disc
#
# Unique values:
#  ['Maybe' 'Yes' 'No']
#
# Frequency of values and data type:
# Maybe    61
# No       50
# Yes      30
# Name: coworker_comfort_mh_disc, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 12, Column name: coworker_reveal_mh_disc
#
# Unique values:
#  [0. 1.]
#
# Frequency of values and data type:
# 0.0    78
# 1.0    63
# Name: coworker_reveal_mh_disc, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 13, Column name: coworker_confine_mh_disc
#
# Unique values:
#  [ 0.  1. nan]
#
# Frequency of values and data type:
# 0.0    79
# 1.0    61
# Name: coworker_confine_mh_disc, dtype: int64
#
# Total value count in column: 140/141
#
# Total NaNs in column: 1
#
# --------------------------------------------------
#
# Index position: 14, Column name: employer_ph_importance
#
# Unique values:
#  [ 4.  8. 10.  9.  5.  6.  7.  3.  0.  2.  1.]
#
# Frequency of values and data type:
# 8.0     38
# 7.0     28
# 5.0     23
# 6.0     13
# 10.0    12
# 9.0      8
# 4.0      7
# 3.0      5
# 2.0      4
# 0.0      2
# 1.0      1
# Name: employer_ph_importance, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 15, Column name: employer_mh_importance
#
# Unique values:
#  [ 4.  8.  2.  6.  0.  9.  5.  7.  3. 10.  1.]
#
# Frequency of values and data type:
# 5.0     32
# 7.0     22
# 4.0     17
# 8.0     16
# 2.0     14
# 3.0     11
# 6.0     10
# 9.0      7
# 0.0      6
# 10.0     5
# 1.0      1
# Name: employer_mh_importance, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 16, Column name: prev_employer
#
# Unique values:
#  [1 0]
#
# Frequency of values and data type:
# 1    108
# 0     33
# Name: prev_employer, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 17, Column name: prev_employer_is_tech_company
#
# Unique values:
#  ['Yes' 'No' 'N/A']
#
# Frequency of values and data type:
# Yes    70
# No     38
# N/A    33
# Name: prev_employer_is_tech_company, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 18, Column name: prev_employer_mh_coverage
#
# Unique values:
#  ['Some did' 'No, none did' nan "I don't know" 'Yes, they all did']
#
# Frequency of values and data type:
# No, none did         43
# Some did             33
# I don't know         20
# Yes, they all did    12
# Name: prev_employer_mh_coverage, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 19, Column name: prev_employer_options_in_mh_coverage
#
# Unique values:
#  ['N/A (was not aware)' 'N/A (none offered)' 'I was aware of some' nan
#  'No, I only became aware later' 'Yes, I was aware of all of them']
#
# Frequency of values and data type:
# N/A (was not aware)                38
# I was aware of some                27
# N/A (none offered)                 23
# Yes, I was aware of all of them    11
# No, I only became aware later       9
# Name: prev_employer_options_in_mh_coverage, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 20, Column name: prev_employer_mh_disc
#
# Unique values:
#  ['None did' 'Yes, they all did' 'Some did' nan "I don't know"]
#
# Frequency of values and data type:
# None did             68
# Some did             28
# I don't know          8
# Yes, they all did     4
# Name: prev_employer_mh_disc, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 21, Column name: prev_employer_offer_mh_res
#
# Unique values:
#  ['Some did' 'None did' nan 'Yes, they all did']
#
# Frequency of values and data type:
# None did             68
# Some did             31
# Yes, they all did     9
# Name: prev_employer_offer_mh_res, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 22, Column name: prev_employer_mh_sa_anonimity
#
# Unique values:
#  ['No' "I don't know" nan 'Sometimes' 'Yes, always']
#
# Frequency of values and data type:
# I don't know    64
# Yes, always     17
# No              15
# Sometimes       12
# Name: prev_employer_mh_sa_anonimity, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 23, Column name: prev_employer_comfort_reveal_ph_mh_disc
#
# Unique values:
#  ['Physical health' 'Same level of comfort for each' nan 'Mental health']
#
# Frequency of values and data type:
# Physical health                   83
# Same level of comfort for each    24
# Mental health                      1
# Name: prev_employer_comfort_reveal_ph_mh_disc, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 24, Column name: prev_supervisor_comfort_mh_disc
#
# Unique values:
#  ['No, none of my previous supervisors' 'Some of my previous supervisors'
#  nan 'Yes, all of my previous supervisors' "I don't know"]
#
# Frequency of values and data type:
# No, none of my previous supervisors    53
# Some of my previous supervisors        43
# Yes, all of my previous supervisors     6
# I don't know                            6
# Name: prev_supervisor_comfort_mh_disc, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 25, Column name: prev_employer_reveal_mh_disc
#
# Unique values:
#  [ 0.  1. nan]
#
# Frequency of values and data type:
# 0.0    88
# 1.0    20
# Name: prev_employer_reveal_mh_disc, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 26, Column name: prev_coworker_comfort_mh_disc
#
# Unique values:
#  ['At some of my previous employers' 'No, at none of my previous employers'
#  nan 'Yes, at all of my previous employers']
#
# Frequency of values and data type:
# At some of my previous employers        50
# No, at none of my previous employers    49
# Yes, at all of my previous employers     9
# Name: prev_coworker_comfort_mh_disc, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 27, Column name: prev_coworker_mh_desc
#
# Unique values:
#  [ 1.  0. nan]
#
# Frequency of values and data type:
# 0.0    71
# 1.0    35
# Name: prev_coworker_mh_desc, dtype: int64
#
# Total value count in column: 106/141
#
# Total NaNs in column: 35
#
# --------------------------------------------------
#
# Index position: 28, Column name: prev_coworker_confine_mh_disc
#
# Unique values:
#  [ 0.  1. nan]
#
# Frequency of values and data type:
# 0.0    78
# 1.0    28
# Name: prev_coworker_confine_mh_disc, dtype: int64
#
# Total value count in column: 106/141
#
# Total NaNs in column: 35
#
# --------------------------------------------------
#
# Index position: 29, Column name: prev_employer_ph_importance
#
# Unique values:
#  [ 1.  5.  0. 10.  8. nan  7.  9.  4.  2.  6.  3.]
#
# Frequency of values and data type:
# 7.0     22
# 5.0     20
# 8.0     16
# 2.0      9
# 10.0     8
# 4.0      7
# 0.0      6
# 9.0      6
# 6.0      6
# 1.0      4
# 3.0      4
# Name: prev_employer_ph_importance, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 30, Column name: prev_employer_mh_importance
#
# Unique values:
#  [ 0.  5.  9.  6. nan  8.  3.  7.  2.  4.  1. 10.]
#
# Frequency of values and data type:
# 5.0     21
# 2.0     20
# 0.0     14
# 3.0     11
# 4.0     11
# 6.0     10
# 7.0      7
# 1.0      6
# 8.0      4
# 9.0      3
# 10.0     1
# Name: prev_employer_mh_importance, dtype: int64
#
# Total value count in column: 108/141
#
# Total NaNs in column: 33
#
# --------------------------------------------------
#
# Index position: 31, Column name: currently_have_mh
#
# Unique values:
#  ['Possibly' "Don't Know" 'Yes' 'No']
#
# Frequency of values and data type:
# No            47
# Possibly      39
# Yes           36
# Don't Know    19
# Name: currently_have_mh, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 32, Column name: diagnosed_mh
#
# Unique values:
#  [nan 'Yes' 'No']
#
# Frequency of values and data type:
# Yes    34
# No      2
# Name: diagnosed_mh, dtype: int64
#
# Total value count in column: 36/141
#
# Total NaNs in column: 105
#
# --------------------------------------------------
#
# Index position: 33, Column name: Anxiety Disorder (Generalized, Social, Phobia, etc).1
#
# Unique values:
#  ['Anxiety Disorder (Generalized, Social, Phobia, etc)' nan]
#
# Frequency of values and data type:
# Anxiety Disorder (Generalized, Social, Phobia, etc)    29
# Name: Anxiety Disorder (Generalized, Social, Phobia, etc).1, dtype: int64
#
# Total value count in column: 29/141
#
# Total NaNs in column: 112
#
# --------------------------------------------------
#
# Index position: 34, Column name: Mood Disorder (Depression, Bipolar Disorder, etc).1
#
# Unique values:
#  [nan 'Mood Disorder (Depression, Bipolar Disorder, etc)']
#
# Frequency of values and data type:
# Mood Disorder (Depression, Bipolar Disorder, etc)    20
# Name: Mood Disorder (Depression, Bipolar Disorder, etc).1, dtype: int64
#
# Total value count in column: 20/141
#
# Total NaNs in column: 121
#
# --------------------------------------------------
#
# Index position: 35, Column name: Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1
#
# Unique values:
#  [nan]
#
# Frequency of values and data type:
# Series([], Name: Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1, dtype: int64)
#
# Total value count in column: 0/141
#
# Total NaNs in column: 141
#
# --------------------------------------------------
#
# Index position: 36, Column name: Eating Disorder (Anorexia, Bulimia, etc).1
#
# Unique values:
#  [nan]
#
# Frequency of values and data type:
# Series([], Name: Eating Disorder (Anorexia, Bulimia, etc).1, dtype: int64)
#
# Total value count in column: 0/141
#
# Total NaNs in column: 141
#
# --------------------------------------------------
#
# Index position: 37, Column name: Attention Deficit Hyperactivity Disorder.1
#
# Unique values:
#  [nan 'Attention Deficit Hyperactivity Disorder']
#
# Frequency of values and data type:
# Attention Deficit Hyperactivity Disorder    9
# Name: Attention Deficit Hyperactivity Disorder.1, dtype: int64
#
# Total value count in column: 9/141
#
# Total NaNs in column: 132
#
# --------------------------------------------------
#
# Index position: 38, Column name: Personality Disorder (Borderline, Antisocial, Paranoid, etc).1
#
# Unique values:
#  [nan 'Personality Disorder (Borderline, Antisocial, Paranoid, etc)']
#
# Frequency of values and data type:
# Personality Disorder (Borderline, Antisocial, Paranoid, etc)    5
# Name: Personality Disorder (Borderline, Antisocial, Paranoid, etc).1, dtype: int64
#
# Total value count in column: 5/141
#
# Total NaNs in column: 136
#
# --------------------------------------------------
#
# Index position: 39, Column name: Obsessive-Compulsive Disorder.1
#
# Unique values:
#  [nan 'Obsessive-Compulsive Disorder']
#
# Frequency of values and data type:
# Obsessive-Compulsive Disorder    3
# Name: Obsessive-Compulsive Disorder.1, dtype: int64
#
# Total value count in column: 3/141
#
# Total NaNs in column: 138
#
# --------------------------------------------------
#
# Index position: 40, Column name: Post-traumatic Stress Disorder.1
#
# Unique values:
#  ['Post-traumatic Stress Disorder' nan]
#
# Frequency of values and data type:
# Post-traumatic Stress Disorder    4
# Name: Post-traumatic Stress Disorder.1, dtype: int64
#
# Total value count in column: 4/141
#
# Total NaNs in column: 137
#
# --------------------------------------------------
#
# Index position: 41, Column name: Stress Response Syndromes.1
#
# Unique values:
#  [nan 'Stress Response Syndromes']
#
# Frequency of values and data type:
# Stress Response Syndromes    9
# Name: Stress Response Syndromes.1, dtype: int64
#
# Total value count in column: 9/141
#
# Total NaNs in column: 132
#
# --------------------------------------------------
#
# Index position: 42, Column name: Dissociative Disorder.1
#
# Unique values:
#  [nan 'Dissociative Disorder']
#
# Frequency of values and data type:
# Dissociative Disorder    2
# Name: Dissociative Disorder.1, dtype: int64
#
# Total value count in column: 2/141
#
# Total NaNs in column: 139
#
# --------------------------------------------------
#
# Index position: 43, Column name: Substance Use Disorder.1
#
# Unique values:
#  [nan]
#
# Frequency of values and data type:
# Series([], Name: Substance Use Disorder.1, dtype: int64)
#
# Total value count in column: 0/141
#
# Total NaNs in column: 141
#
# --------------------------------------------------
#
# Index position: 44, Column name: Addictive Disorder.1
#
# Unique values:
#  [nan]
#
# Frequency of values and data type:
# Series([], Name: Addictive Disorder.1, dtype: int64)
#
# Total value count in column: 0/141
#
# Total NaNs in column: 141
#
# --------------------------------------------------
#
# Index position: 45, Column name: Other.1
#
# Unique values:
#  [nan]
#
# Frequency of values and data type:
# Series([], Name: Other.1, dtype: int64)
#
# Total value count in column: 0/141
#
# Total NaNs in column: 141
#
# --------------------------------------------------
#
# Index position: 46, Column name: Anxiety Disorder (Generalized, Social, Phobia, etc).2
#
# Unique values:
#  [nan 'Anxiety Disorder (Generalized, Social, Phobia, etc)']
#
# Frequency of values and data type:
# Anxiety Disorder (Generalized, Social, Phobia, etc)    18
# Name: Anxiety Disorder (Generalized, Social, Phobia, etc).2, dtype: int64
#
# Total value count in column: 18/141
#
# Total NaNs in column: 123
#
# --------------------------------------------------
#
# Index position: 47, Column name: Mood Disorder (Depression, Bipolar Disorder, etc).2
#
# Unique values:
#  [nan 'Mood Disorder (Depression, Bipolar Disorder, etc)']
#
# Frequency of values and data type:
# Mood Disorder (Depression, Bipolar Disorder, etc)    28
# Name: Mood Disorder (Depression, Bipolar Disorder, etc).2, dtype: int64
#
# Total value count in column: 28/141
#
# Total NaNs in column: 113
#
# --------------------------------------------------
#
# Index position: 48, Column name: Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2
#
# Unique values:
#  [nan 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)']
#
# Frequency of values and data type:
# Psychotic Disorder (Schizophrenia, Schizoaffective, etc)    2
# Name: Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2, dtype: int64
#
# Total value count in column: 2/141
#
# Total NaNs in column: 139
#
# --------------------------------------------------
#
# Index position: 49, Column name: Eating Disorder (Anorexia, Bulimia, etc).2
#
# Unique values:
#  [nan 'Eating Disorder (Anorexia, Bulimia, etc)']
#
# Frequency of values and data type:
# Eating Disorder (Anorexia, Bulimia, etc)    1
# Name: Eating Disorder (Anorexia, Bulimia, etc).2, dtype: int64
#
# Total value count in column: 1/141
#
# Total NaNs in column: 140
#
# --------------------------------------------------
#
# Index position: 50, Column name: Attention Deficit Hyperactivity Disorder.2
#
# Unique values:
#  [nan 'Attention Deficit Hyperactivity Disorder']
#
# Frequency of values and data type:
# Attention Deficit Hyperactivity Disorder    7
# Name: Attention Deficit Hyperactivity Disorder.2, dtype: int64
#
# Total value count in column: 7/141
#
# Total NaNs in column: 134
#
# --------------------------------------------------
#
# Index position: 51, Column name: Personality Disorder (Borderline, Antisocial, Paranoid, etc).2
#
# Unique values:
#  [nan 'Personality Disorder (Borderline, Antisocial, Paranoid, etc)']
#
# Frequency of values and data type:
# Personality Disorder (Borderline, Antisocial, Paranoid, etc)    3
# Name: Personality Disorder (Borderline, Antisocial, Paranoid, etc).2, dtype: int64
#
# Total value count in column: 3/141
#
# Total NaNs in column: 138
#
# --------------------------------------------------
#
# Index position: 52, Column name: Obsessive-Compulsive Disorder.2
#
# Unique values:
#  [nan 'Obsessive-Compulsive Disorder']
#
# Frequency of values and data type:
# Obsessive-Compulsive Disorder    2
# Name: Obsessive-Compulsive Disorder.2, dtype: int64
#
# Total value count in column: 2/141
#
# Total NaNs in column: 139
#
# --------------------------------------------------
#
# Index position: 53, Column name: Post-traumatic Stress Disorder.2
#
# Unique values:
#  [nan 'Post-traumatic Stress Disorder']
#
# Frequency of values and data type:
# Post-traumatic Stress Disorder    5
# Name: Post-traumatic Stress Disorder.2, dtype: int64
#
# Total value count in column: 5/141
#
# Total NaNs in column: 136
#
# --------------------------------------------------
#
# Index position: 54, Column name: Stress Response Syndromes.2
#
# Unique values:
#  [nan 'Stress Response Syndromes']
#
# Frequency of values and data type:
# Stress Response Syndromes    2
# Name: Stress Response Syndromes.2, dtype: int64
#
# Total value count in column: 2/141
#
# Total NaNs in column: 139
#
# --------------------------------------------------
#
# Index position: 55, Column name: Dissociative Disorder.2
#
# Unique values:
#  [nan]
#
# Frequency of values and data type:
# Series([], Name: Dissociative Disorder.2, dtype: int64)
#
# Total value count in column: 0/141
#
# Total NaNs in column: 141
#
# --------------------------------------------------
#
# Index position: 56, Column name: Substance Use Disorder.2
#
# Unique values:
#  [nan 'Substance Use Disorder']
#
# Frequency of values and data type:
# Substance Use Disorder    4
# Name: Substance Use Disorder.2, dtype: int64
#
# Total value count in column: 4/141
#
# Total NaNs in column: 137
#
# --------------------------------------------------
#
# Index position: 57, Column name: Addictive Disorder.2
#
# Unique values:
#  [nan 'Addictive Disorder']
#
# Frequency of values and data type:
# Addictive Disorder    2
# Name: Addictive Disorder.2, dtype: int64
#
# Total value count in column: 2/141
#
# Total NaNs in column: 139
#
# --------------------------------------------------
#
# Index position: 58, Column name: Other.2
#
# Unique values:
#  [nan 'Autism Spectrum Disorder']
#
# Frequency of values and data type:
# Autism Spectrum Disorder    1
# Name: Other.2, dtype: int64
#
# Total value count in column: 1/141
#
# Total NaNs in column: 140
#
# --------------------------------------------------
#
# Index position: 59, Column name: past_mh
#
# Unique values:
#  ['Possibly' 'No' 'Yes' "Don't Know" nan]
#
# Frequency of values and data type:
# No            54
# Yes           47
# Possibly      26
# Don't Know    12
# Name: past_mh, dtype: int64
#
# Total value count in column: 139/141
#
# Total NaNs in column: 2
#
# --------------------------------------------------
#
# Index position: 60, Column name: sought_mh_treatment
#
# Unique values:
#  [0 1]
#
# Frequency of values and data type:
# 0    78
# 1    63
# Name: sought_mh_treatment, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 61, Column name: mh_family_history
#
# Unique values:
#  ['Yes' 'No' "I don't know"]
#
# Frequency of values and data type:
# No              70
# Yes             44
# I don't know    27
# Name: mh_family_history, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 62, Column name: mh_with_treatment_impact_on_work
#
# Unique values:
#  ['Sometimes' 'Never' 'Rarely' 'Often' 'Not applicable to me']
#
# Frequency of values and data type:
# Not applicable to me    61
# Sometimes               31
# Rarely                  28
# Often                   15
# Never                    6
# Name: mh_with_treatment_impact_on_work, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 63, Column name: mh_with_no_treatment_impact_on_work
#
# Unique values:
#  ['Sometimes' 'Never' 'Often' 'Rarely' 'Not applicable to me']
#
# Frequency of values and data type:
# Often                   52
# Not applicable to me    51
# Sometimes               22
# Rarely                  10
# Never                    6
# Name: mh_with_no_treatment_impact_on_work, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 64, Column name: others_mh_reveal_impact_on_mh_self_reveal
#
# Unique values:
#  ['Maybe' nan 'Yes' 'No']
#
# Frequency of values and data type:
# No       57
# Maybe    31
# Yes      22
# Name: others_mh_reveal_impact_on_mh_self_reveal, dtype: int64
#
# Total value count in column: 110/141
#
# Total NaNs in column: 31
#
# --------------------------------------------------
#
# Index position: 65, Column name: friends_fam_mh_reveal
#
# Unique values:
#  [ 3  7  0  9  8  1  5  4  2  6 10]
#
# Frequency of values and data type:
# 8     29
# 5     22
# 7     20
# 9     16
# 10    15
# 3      9
# 6      8
# 4      7
# 0      5
# 1      5
# 2      5
# Name: friends_fam_mh_reveal, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 66, Column name: future_employer_ph_reveal
#
# Unique values:
#  ['Yes' 'No' 'Maybe']
#
# Frequency of values and data type:
# Maybe    52
# No       45
# Yes      44
# Name: future_employer_ph_reveal, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 67, Column name: future_employer_mh_reveal
#
# Unique values:
#  ['No' 'Maybe' 'Yes']
#
# Frequency of values and data type:
# No       89
# Maybe    39
# Yes      13
# Name: future_employer_mh_reveal, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 68, Column name: identified_mh_at_work
#
# Unique values:
#  [0 1]
#
# Frequency of values and data type:
# 0    123
# 1     18
# Name: identified_mh_at_work, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 69, Column name: identified_mh_at_work_has_effected
#
# Unique values:
#  [nan  1.  0.]
#
# Frequency of values and data type:
# 0.0    9
# 1.0    8
# Name: identified_mh_at_work_has_effected, dtype: int64
#
# Total value count in column: 17/141
#
# Total NaNs in column: 124
#
# --------------------------------------------------
#
# Index position: 70, Column name: identified_mh_at_work_how_effected
#
# Unique values:
#  [nan  2.  4.  0.  7.  6.]
#
# Frequency of values and data type:
# 2.0    3
# 4.0    2
# 0.0    1
# 7.0    1
# 6.0    1
# Name: identified_mh_at_work_how_effected, dtype: int64
#
# Total value count in column: 8/141
#
# Total NaNs in column: 133
#
# --------------------------------------------------
#
# Index position: 71, Column name: if_coworker_knew_of_my_mh_results
#
# Unique values:
#  [ 3  6  0  7  2  8  4  1  5  9 10]
#
# Frequency of values and data type:
# 5     36
# 3     18
# 8     18
# 6     17
# 2     16
# 7     14
# 4      6
# 0      5
# 10     5
# 1      4
# 9      2
# Name: if_coworker_knew_of_my_mh_results, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 72, Column name: mh_bad_response_at_work
#
# Unique values:
#  ['Yes, I observed' 'No' 'Maybe/Not sure' 'Yes, I experienced']
#
# Frequency of values and data type:
# No                    63
# Maybe/Not sure        35
# Yes, I observed       25
# Yes, I experienced    18
# Name: mh_bad_response_at_work, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 73, Column name: mh_positive_response_at_work_desc
#
# Unique values:
#  ['Yes, I observed' 'Maybe/Not sure' 'No' 'Yes, I experienced']
#
# Frequency of values and data type:
# No                    55
# Maybe/Not sure        34
# Yes, I experienced    27
# Yes, I observed       25
# Name: mh_positive_response_at_work_desc, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 74, Column name: tech_industry_mh_support
#
# Unique values:
#  [4 3 2 1 5]
#
# Frequency of values and data type:
# 3    62
# 2    37
# 4    24
# 1    14
# 5     4
# Name: tech_industry_mh_support, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 75, Column name: survey_creators_comfort_reveal
#
# Unique values:
#  [1 0]
#
# Frequency of values and data type:
# 0    94
# 1    47
# Name: survey_creators_comfort_reveal, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 76, Column name: age
#
# Unique values:
#  [26 32 34 44 33 38 45 27 21 30 39 24 50 28 42 22 36 29 58 40 48 37 31 35
#  46 54 23 20 59 53 62 47 25 52 43]
#
# Frequency of values and data type:
# 30    11
# 32    11
# 34     9
# 27     7
# 42     6
# 24     6
# 40     6
# 26     6
# 29     6
# 31     6
# 33     5
# 44     5
# 28     5
# 39     5
# 37     4
# 23     4
# 36     3
# 21     3
# 25     3
# 48     3
# 22     3
# 45     3
# 46     3
# 53     2
# 50     2
# 47     2
# 62     2
# 38     2
# 35     2
# 43     1
# 52     1
# 54     1
# 58     1
# 59     1
# 20     1
# Name: age, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 77, Column name: gender
#
# Unique values:
#  ['male' 'Male' 'female' 'M' 'm' 'F' 'Female' 'f' 'Woman' nan 'FEMALE'
#  'female, she/her' 'mostly male' 'cisgender male' 'MAle']
#
# Frequency of values and data type:
# Male               60
# male               26
# female             17
# Female             15
# F                   8
# M                   4
# Woman               2
# m                   2
# mostly male         1
# female, she/her     1
# f                   1
# cisgender male      1
# MAle                1
# FEMALE              1
# Name: gender, dtype: int64
#
# Total value count in column: 140/141
#
# Total NaNs in column: 1
#
# --------------------------------------------------
#
# Index position: 78, Column name: country_live
#
# Unique values:
#  ['United States of America' 'India' 'Philippines' 'Sri Lanka' 'Brazil'
#  'Poland' 'Taiwan' 'Australia' 'United Kingdom' 'Indonesia' 'Netherlands'
#  'Chile' 'Portugal' 'South Africa' 'Germany' 'Canada' 'Spain' 'Sweden'
#  'Mongolia' 'Serbia' 'Egypt' 'Ukraine' 'Turkey' 'France' 'Bangladesh'
#  'Ireland']
#
# Frequency of values and data type:
# United States of America    57
# India                       24
# Canada                       7
# Spain                        6
# Brazil                       6
# United Kingdom               5
# Netherlands                  4
# Germany                      4
# Philippines                  3
# Australia                    3
# Sweden                       2
# South Africa                 2
# Poland                       2
# Indonesia                    2
# Sri Lanka                    2
# France                       2
# Mongolia                     1
# Egypt                        1
# Ukraine                      1
# Chile                        1
# Bangladesh                   1
# Portugal                     1
# Serbia                       1
# Taiwan                       1
# Turkey                       1
# Ireland                      1
# Name: country_live, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------
#
# Index position: 79, Column name: race
#
# Unique values:
#  ['White' nan 'More than one of the above' 'Asian' 'I prefer not to answer'
#  'Black or African American']
#
# Frequency of values and data type:
# White                         41
# Asian                         12
# More than one of the above     1
# I prefer not to answer         1
# Black or African American      1
# Name: race, dtype: int64
#
# Total value count in column: 56/141
#
# Total NaNs in column: 85
#
# --------------------------------------------------
#
# Index position: 80, Column name: Other.3
#
# Unique values:
#  [nan 'Latino ']
#
# Frequency of values and data type:
# Latino     1
# Name: Other.3, dtype: int64
#
# Total value count in column: 1/141
#
# Total NaNs in column: 140
#
# --------------------------------------------------
#
# Index position: 81, Column name: country_work
#
# Unique values:
#  ['United States of America' 'India' 'Philippines' 'Sri Lanka' 'Brazil'
#  'Poland' 'Taiwan' 'Australia' 'United Kingdom' 'Indonesia' 'Netherlands'
#  'Portugal' 'South Africa' 'Germany' 'Canada' 'Spain' 'Sweden' 'Mongolia'
#  'Serbia' 'Egypt' 'Finland' 'Turkey' 'France' 'Bangladesh' 'Ireland']
#
# Frequency of values and data type:
# United States of America    59
# India                       23
# Canada                       7
# Spain                        6
# Brazil                       6
# United Kingdom               5
# Netherlands                  4
# Germany                      4
# Australia                    3
# Philippines                  3
# Indonesia                    2
# France                       2
# Poland                       2
# South Africa                 2
# Sweden                       2
# Sri Lanka                    2
# Taiwan                       1
# Mongolia                     1
# Bangladesh                   1
# Portugal                     1
# Serbia                       1
# Finland                      1
# Ireland                      1
# Egypt                        1
# Turkey                       1
# Name: country_work, dtype: int64
#
# Total value count in column: 141/141
#
# Total NaNs in column: 0
#
# --------------------------------------------------

# %%
#N/A values will be replaced with -1. That way "No" will always start as "0" and the more positive the response the higher
#numeric value it has

#Replace values of: "num_employees"
col_name = "num_employees"
col_data = {
    "01-May":1, #Most likely an error, May is the 5th month so it's safe to assume that the range is "01-05"
    "Jun-25":6, #Most likely an error, June is the 6th month so it's safe to assume that the range is "06-25"
    "26-100":26,
    "100-500":101,
    "500-1000":501,
    "More than 1000":1001
}
surveyC1[col_name] = surveyC1[col_name].replace(col_data)

#Replace values of: "employer_mh_coverage"
col_name = "employer_mh_coverage"
col_data = {
    "Yes":2,
    "I don't know":1,
    "No":0,
    "Not eligible for coverage / NA":-1,
}
surveyC1[col_name] = surveyC1[col_name].replace(col_data)

#Replace values of: "employer_options_in_mh_coverage"
col_name = "employer_options_in_mh_coverage"
col_data = {
    "Yes":1,
    "No":0,
}
surveyC1[col_name] = surveyC1[col_name].fillna(-1) 
surveyC1[col_name] = surveyC1[col_name].replace(col_data)

#Replace values of: "employer_mh_disc"
col_name = "employer_mh_disc"
col_data = {
    "Yes":2,
    "I don't know":1,
    "No":0
}
surveyC1[col_name] = surveyC1[col_name].fillna(-1)
surveyC1[col_name] = surveyC1[col_name].replace(col_data)

#Replace values of: "employer_offer_mh_res"
col_name = "employer_offer_mh_res"
col_data = {
    "Yes":2,
    "I don't know":1,
    "No":0
}
surveyC1[col_name] = surveyC1[col_name].replace(col_data)

#Replace values of: "employer_mh_sa_anonimity"
col_name = "employer_mh_sa_anonimity"
col_data = {
    "Yes": 2,
    "I don't know":1,
    "No":0
}
surveyC1[col_name] = surveyC1[col_name].replace(col_data)

#Replace values of: "employer_mh_leave_difficulty"
col_name = "employer_mh_leave_difficulty"
col_data ={
    "Very easy": 5,
    "Somewhat easy":4,
    "Neither easy nor difficult":3,
    "I don't know": 3,
    "Somewhat difficult":2,
    "Difficult":1,
}
surveyC1[col_name] = surveyC1[col_name].replace(col_data)

#Replace values of: "coworker_comfort_reveal_ph_mh_disc"
col_name = "coworker_comfort_reveal_ph_mh_disc"
col_data = {
    "Physical health":2,
    "Mental health":1,
    "Same level of comfort for each":0
}

surveyC1[col_name] = surveyC1[col_name].replace(col_data)

#Replace values of: "supervisor_comfort_mh_disc"
col_name = "supervisor_comfort_mh_disc"
col_data = {
    "Yes":2,
    "Maybe":1,
    "No":0
}

surveyC1[col_name] = surveyC1[col_name].replace(col_data)

# %%
surveyC1["supervisor_comfort_mh_disc"].value_counts(dropna=False)
# Out:
# 0    55
# 1    47
# 2    39
# Name: supervisor_comfort_mh_disc, dtype: int64

# %% [markdown]
# ## 2.d Company type and job role

# %%
#It seems that 97 companies are in tech
surveyC1["is_tech_company"].value_counts()
# Out:
# 1.0    97
# 0.0    58
# Name: is_tech_company, dtype: int64

# %%
#Only 14 people don't consider their roles being in tech/IT
#This is a better representation of what we're looking for
surveyC1["is_role_in_tech"].value_counts()
# Out:
# 1.0    141
# 0.0     14
# Name: is_role_in_tech, dtype: int64

# %%
#We'll drop the 14 whose primary job role isn't tech/IT
surveyC1 = surveyC1[surveyC1["is_role_in_tech"].isin([1])]
surveyC1.shape
# Out:
# (141, 83)

# %%
#Next, we'll drop "is_tech_company" and rename "is_role_in_tech" 
surveyC1 = surveyC1.drop(["is_tech_company"], axis=1)
surveyC1 = surveyC1.rename(columns={"is_role_in_tech":"is_comp_role_in_tech"})

# %%
#Function to convert: NaN, 0.0, 1.0 -> "N/A", "No", "Yes" and plot
#def value_to_y_n_na(column, bins, rwidth):
#        surveyC1[column].fillna("N/A", inplace=True)
#        surveyC1[column].replace(to_replace=0.0, value="No", inplace=True)
#        surveyC1[column].replace(to_replace=1.0, value="Yes", inplace=True)
        
#        plt.figure(figsize=(10, 4))
#        n, bins, patches = plt.hist(surveyC1[column], bins=bins, rwidth=rwidth)

# %%
#surveyC1["num_employees"].value_counts()

# %%
#surveyC1["num_employees"].replace(to_replace="01-May", value="1-5", inplace=True)
#surveyC1["num_employees"].replace(to_replace="Jun-25", value="6-25", inplace=True)
#surveyC1["num_employees"].fillna(0, inplace=True)

#The data types are mixed, so we want a single data type for the whole column
#for ease of use 
#surveyC1["num_employees"].astype(str).astype(str)

# %% [markdown]
# - Change "prev_employer_is_tech_company", "is_role_in_tech" column
#     - NaN to "N/A", 0.0 to "No" and 1.0 to "Yes"

# %%
#value_to_y_n_na(column="prev_employer_is_tech_company", bins=3, rwidth=0.9)

# %% [markdown]
# - Change "employer_mh_coverage" column
#     - NaN and "" to "N/A"

# %%
#surveyC1["employer_mh_coverage"].value_counts(dropna=False)

# %%
#surveyC1["employer_mh_coverage"].fillna("N/A", inplace=True)
#surveyC1["employer_mh_coverage"].replace(to_replace="Not eligible for coverage / NA",
#                                        value="N/A", inplace=True)

# %% [markdown]
# - Change "prev_employer_mh_coverage" column
#     - "Yes, they all did" to "Yes", "No, none did" to "No"

# %%
surveyC1["prev_employer_mh_coverage"].value_counts()

# %%
#For column "If possibly, what disorder(s) do you believe you have?", 
#"Anxiety Disorder (Generalized, Social, Phobia, etc).1"
#needs to be 74.5%

mh1 = surveyC1["Anxiety Disorder (Generalized, Social, Phobia, etc).1"]
mh2 = surveyC1["Anxiety Disorder (Generalized, Social, Phobia, etc).2"]
print(mh1, mh2)

##For column "If so, what disorder(s) were you diagnosed with?", 
#"Anxiety Disorder (Generalized, Social, Phobia, etc).2"
#needs to be 55.3%

# %% [markdown]
# - Change and encode mental health disorders

# %%
#We saw that there was a disorder that wasn't accounted for (stated in "Ither"): Autism Spectrum Disorder
#Change columns: "Other.1" and "Other.2" to "Autism Spectrum Disorder.1" and "Autism Spectrum Disorder.2" respectively
surveyC1.rename(columns={
    "Other.1":"Autism Spectrum Disorder.1",
    "Other.2":"Autism Spectrum Disorder.2"},
               inplace=True
              )

# %%
mh_list = [
    "Anxiety Disorder (Generalized, Social, Phobia, etc).1",
    "Mood Disorder (Depression, Bipolar Disorder, etc).1",
    "Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1",
    "Eating Disorder (Anorexia, Bulimia, etc).1",
    "Attention Deficit Hyperactivity Disorder.1",
    "Personality Disorder (Borderline, Antisocial, Paranoid, etc).1",
    "Obsessive-Compulsive Disorder.1",
    "Post-traumatic Stress Disorder.1",
    "Stress Response Syndromes.1",
    "Dissociative Disorder.1",
    "Substance Use Disorder.1",
    "Addictive Disorder.1",
    "Autism Spectrum Disorder.1", 
    "Anxiety Disorder (Generalized, Social, Phobia, etc).2",
    "Mood Disorder (Depression, Bipolar Disorder, etc).2",
    "Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2",
    "Eating Disorder (Anorexia, Bulimia, etc).2",
    "Attention Deficit Hyperactivity Disorder.2",
    "Personality Disorder (Borderline, Antisocial, Paranoid, etc).2",
    "Obsessive-Compulsive Disorder.2",
    "Post-traumatic Stress Disorder.2",
    "Stress Response Syndromes.2",
    "Dissociative Disorder.2",
    "Substance Use Disorder.2",
    "Addictive Disorder.2",
    "Autism Spectrum Disorder.2"
]

for i in range(len(mh_list)):
    surveyC1[[mh_list[i]]] = surveyC1[[mh_list[i]]].applymap(lambda x: 0 if pd.isnull(x) else 1)

# %% [markdown]
# - Change and encode gender column

# %%
#Make all values to lowercase and see the unique values
#surveyC1["gender"].uniqe()
surveyC1["gender"] = surveyC1["gender"].str.lower()

# %%
#Categorize gender into: male, female, other
male_str = ["male", "mail", "m", "mostyl male", "mostly male", "cisgender male"]
fmale_str = ["female", "f", "woman", "she/her", "female, she/her"]

#Iterate through dataset and change the values
for (row, column) in surveyC1.iterrows():
    if column["gender"] in male_str:
        surveyC1["gender"].replace(to_replace=column["gender"],
                                              value=1, inplace=True)
    elif column["gender"] in fmale_str:
        surveyC1["gender"].replace(to_replace=column["gender"],
                                               value=2, inplace=True)
    else: 
        surveyC1["gender"].fillna(3, inplace=True)

# %%
surveyC1["gender"].value_counts()

# %%
#Example of a scenario to do a for loop, Series has a property of value_counts
#print(surveyC1["What is your gender?"].value_counts().male)
#print(surveyC1["What is your gender?"].value_counts().female)
#def count_str_occurences(df, column, values=[]):
#    total_instances = 0
#    if len(values) == 0 or None:
#        print("Please insert string values for 'values' in the following manner: values=['val1', 'val2']")
#    else:
#        for i in range(len(values)):
#            total_instances += df[column].value_counts().values[i]
#            print("For '{}', there's {} instances".format(values[i], df[column].value_counts().values[i]))
#    print("-"*20)
#    print("Total instances:", total_instances)
            
#count_str_occurences(surveyC, "gender", values=['male', 'female', 'other'])

# %%
#Plot age and gender in each country
#plt.figure(figsize=(12, 8))
#x = sns.barplot(x="country_live",
#                y="age",
#                hue="gender",
#                data=surveyC1)

#If x and y axes are shifted
#for item in x.get_xticklabels():
#    item.set_rotation(90)

# %% [markdown]
# - race

# %%
#Change NaN to "I prefer not to answer"
surveyC1["race"].fillna("I prefer not to answer", inplace=True)

# %%
#Check which user inserted Latino, there should be a race column 
surveyC1.loc[surveyC1["Other.3"] == "Latino "] #Gets more information about the user

# %%
#Fill in "Latino" value for user 39 in race column
surveyC1.loc[[39], "race"] = "Latino"

# %%
#Drop "Other.3" column
surveyC1 = surveyC1.drop("Other.3", axis=1)

# %% [markdown]
# # 3. Visualizations

# %% [markdown]
# ##### Find countries column

# %% [markdown]
# Lets plot the countries to have a better understanding
#
# https://stackoverflow.com/questions/43214978/seaborn-barplot-displaying-values/51535326#51535326

# %%
user_country = surveyC1["country_live"].value_counts()

# %%
plt.figure(figsize=(8, 7))
sns_country = sns.barplot(x=user_country.values, y=user_country.index, 
                          palette=("Blues_d"))
plt.xlabel("Number of responds", fontsize=18)
plt.ylabel("Country", fontsize=18)

def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

show_values_on_bars(sns_country, "h", 0.3)

# %% [markdown]
# # Classifiers

# %% [markdown]
# We'll try to predict how likely someone is to look for treatment (sought_mh_treatment) based on:
# - personal information
# - thier experiences (past and present)

# %%
feature_list_ref = {
    "How many employees does your company or organization have?":"num_employees",
    "Does your employer provide mental health benefits as part of healthcare coverage?":"cep_benefits",
    "Do you know the options for mental health care available under your employer-provided coverage?":"cep_know_options",
    "Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?":"cep_discuss",
    "Does your employer offer resources to learn more about mental health concerns and options for seeking help?":"cep_learn",
    "Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?":"cep_anon",
    "If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:":"cep_mh_leave",
    "Do you think that discussing a mental health disorder with your employer would have negative consequences?":"cep_mh_ncsq",
    "Do you think that discussing a physical health issue with your employer would have negative consequences?":"cep_ph_ncsq",
    "Would you feel comfortable discussing a mental health disorder with your coworkers?":"cep_comf_cw",
    "Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?":"cep_comf_sup",
    "Do you feel that your employer takes mental health as seriously as physical health?":"cep_serious",
    "Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?":"cep_others_ncsq",
    "Do you have previous employers?":"pep_have",
    "Have your previous employers provided mental health benefits?":"pep_benefits",
    "Were you aware of the options for mental health care provided by your previous employers?":"pep_know_options",
    "Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?":"pep_discuss",
    "Did your previous employers provide resources to learn more about mental health issues and how to seek help?":"pep_learn",
    "Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?":"pep_anon",
    "Do you think that discussing a mental health disorder with previous employers would have negative consequences?":"pep_mh_ncsq",
    "Do you think that discussing a physical health issue with previous employers would have negative consequences?":"pep_ph_ncsq",
    "Would you have been willing to discuss a mental health issue with your previous co-workers?":"pep_comf_cw",
    "Would you have been willing to discuss a mental health issue with your direct supervisor(s)?":"pep_comf_sup",
    "Did you feel that your previous employers took mental health as seriously as physical health?":"pep_serious",
    "Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?":"pep_others_ncsq",
    "Would you be willing to bring up a physical health issue with a potential employer in an interview?":"fep_ph_willing",
    "Would you bring up a mental health issue with a potential employer in an interview?":"fep_mh_willing",
    "Do you feel that being identified as a person with a mental health issue would hurt your career?":"hurt_career",
    "Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?":"cw_view_neg",
    "How willing would you be to share with friends and family that you have a mental illness?":"comf_ff",
    "Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?":"neg_response",
    "Do you have a family history of mental illness?":"mh_fam_hist",
    "Have you had a mental health disorder in the past?":"mh_hist",
    "Do you currently have a mental health disorder?":"mh_cur",
    "Have you been diagnosed with a mental health condition by a medical professional?":"mh_diag_pro",
    "Have you ever sought treatment for a mental health issue from a mental health professional?":"sought_treat",
    "If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?":"work_affect_effect",
    "If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?":"work_affect_ineffect",
    "What is your age?":"age",
    "What is your gender?":"gender",
    "What country do you work in?":"work_country",
    "Do you work remotely?":"work_remote"
}

# %%
feature_list_comp = {
    #my project / reference
    "num_employees":"num_employees",
    "is_comp_role_in_tech":"tech_company_or_role",
    "employer_mh_coverage":"cep_benefits",
    "employer_options_in_mh_coverage":None,
    "employer_mh_disc":"cep_discuss",
    "employer_offer_mh_res":None,
    "employer_mh_sa_anonimity":"cep_anon",
    "employer_mh_leave_difficulty":None,
    "coworker_comfort_reveal_ph_mh_disc":None,
    "supervisor_comfort_mh_disc":None
}

# %%
#Look at the column names
#surveyC1.columns.tolist()

# %%
#Make X and y
#personal_list contains all personal information relating the user
personal_list = ["num_employees", "is_comp_role_in_tech"]

#exp_list contains all past and current experience the user has relating mental health disorders
exp_list = ["employer_mh_coverage", "employer_options_in_mh_coverage", "employer_mh_disc", "employer_offer_mh_res",
            "employer_mh_sa_anonimity", "employer_mh_leave_difficulty", "coworker_comfort_reveal_ph_mh_disc", "supervisor_comfort_mh_disc"]
